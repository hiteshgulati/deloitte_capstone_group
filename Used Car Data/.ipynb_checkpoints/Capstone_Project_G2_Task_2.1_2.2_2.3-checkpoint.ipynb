# %% [markdown]
# # Azure Batch - G2

# %% [markdown]
# ## Domain:
# #### Automobile Industry
#
# ## About:
# #### The XYZ automobile company in India wants to enter the business of selling used cars. They would like to analyse the business challenges before the venture.

# %% [markdown]
# #### Importing all the libraries

# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None 
from IPython.display import display
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# #### Importing File Car_Sales CSV File and displaying first 5 entries of our Data Set

# %%
car_data = pd.read_csv('Car_sales_transactions.csv', sep=",",header = 0, encoding='latin')
car_data.head()
# Out:
#    Sales_ID                          Name  Year  Selling_Price  km_Driven  \
# 0         1        Maruti Swift Dzire VDI  2014         450000     145500
# 1         2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         3      Honda City 2017-2020 EXi  2006         158000     140000
# 3         4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4         5        Maruti Swift VXI BSIII  2007         130000     120000
#
#   City_Code State_Code  Postal_Code    Fuel Seller_Type Transmission  \
# 0      CT01       ST15       400001  Diesel  Individual       Manual
# 1      CT28       ST11       834001  Diesel  Individual       Manual
# 2      CT12       ST28       201301  Petrol  Individual       Manual
# 3      CT21       ST27       248001  Diesel  Individual       Manual
# 4      CT03       ST24       600020  Petrol  Individual       Manual
#
#           Owner     Mileage   Engine   Max_Power  Seats
# 0   First Owner   23.4 kmpl  1248 CC      74 bhp      5
# 1  Second Owner  21.14 kmpl  1498 CC  103.52 bhp      5
# 2   Third Owner   17.7 kmpl  1497 CC      78 bhp      5
# 3   First Owner   23.0 kmpl  1396 CC      90 bhp      5
# 4   First Owner   16.1 kmpl  1298 CC    88.2 bhp      5

# %%
car_data.shape
# Out:
# (7906, 16)

# %% [markdown]
# #### Displaying all the column names.

# %%
car_data.columns
# Out:
# Index(['Sales_ID', 'Name', 'Year', 'Selling_Price', 'km_Driven', 'City_Code',
#        'State_Code', 'Postal_Code', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Mileage', 'Engine', 'Max_Power', 'Seats'],
#       dtype='object')

# %% [markdown]
# #### Importing data from Sales Status and City Master File and merging it with the data and displaying first five entries

# %%
sales_status = pd.read_csv('Sales_Status.csv')
city_master = pd.read_excel('City_Master.xlsx')
region = pd.read_excel('Region_Master.xlsx')
region_state = pd.read_excel('Region_State_Mapping.xlsx')
state = pd.read_excel('State_Master.xlsx')
car_data = pd.merge(car_data,city_master[['City_Code','City_Name']],how ='left',on='City_Code')
car_data = pd.merge(car_data,region_state, how ='left',on='State_Code')
car_data = pd.merge(car_data,sales_status, how = 'left', on='Sales_ID')
car_data = pd.merge(car_data,state, how = 'left', on='State_Code')
car_data = pd.merge(car_data,region, how = 'left', on='Region_Code')
car_data.head()
# Out:
#    Sales_ID                          Name  Year  Selling_Price  km_Driven  \
# 0         1        Maruti Swift Dzire VDI  2014         450000     145500
# 1         2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         3      Honda City 2017-2020 EXi  2006         158000     140000
# 3         4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4         5        Maruti Swift VXI BSIII  2007         130000     120000
#
#   City_Code State_Code  Postal_Code    Fuel Seller_Type  ...         Owner  \
# 0      CT01       ST15       400001  Diesel  Individual  ...   First Owner
# 1      CT28       ST11       834001  Diesel  Individual  ...  Second Owner
# 2      CT12       ST28       201301  Petrol  Individual  ...   Third Owner
# 3      CT21       ST27       248001  Diesel  Individual  ...   First Owner
# 4      CT03       ST24       600020  Petrol  Individual  ...   First Owner
#
#       Mileage   Engine   Max_Power Seats  City_Name Region_Code Sold  \
# 0   23.4 kmpl  1248 CC      74 bhp     5     Mumbai          R3    Y
# 1  21.14 kmpl  1498 CC  103.52 bhp     5     Ranchi          R2    Y
# 2   17.7 kmpl  1497 CC      78 bhp     5      Noida          R1    Y
# 3   23.0 kmpl  1396 CC      90 bhp     5   Dehradun          R1    Y
# 4   16.1 kmpl  1298 CC    88.2 bhp     5    Chennai          R4    Y
#
#       State_Name   Region
# 0    Maharashtra     West
# 1      Jharkhand     East
# 2  Uttar Pradesh  Central
# 3    Uttarakhand  Central
# 4     Tamil Nadu    South
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Checking the datatypes of our dataset

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7906 entries, 0 to 7905
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales_ID       7906 non-null   int64
#  1   Name           7906 non-null   object
#  2   Year           7906 non-null   int64
#  3   Selling_Price  7906 non-null   int64
#  4   km_Driven      7906 non-null   int64
#  5   City_Code      7906 non-null   object
#  6   State_Code     7906 non-null   object
#  7   Postal_Code    7906 non-null   int64
#  8   Fuel           7906 non-null   object
#  9   Seller_Type    7906 non-null   object
#  10  Transmission   7906 non-null   object
#  11  Owner          7906 non-null   object
#  12  Mileage        7906 non-null   object
#  13  Engine         7906 non-null   object
#  14  Max_Power      7906 non-null   object
#  15  Seats          7906 non-null   int64
#  16  City_Name      7906 non-null   object
#  17  Region_Code    7906 non-null   object
#  18  Sold           7906 non-null   object
#  19  State_Name     7906 non-null   object
#  20  Region         7906 non-null   object
# dtypes: int64(6), object(15)
# memory usage: 1.3+ MB

# %% [markdown]
# #### Coverting Mileage, Power and Engine from String to Float Values

# %%
car_data['Mileage_float'] = car_data['Mileage'].str[:-5]
car_data['Power'] = car_data['Max_Power'].str[:-4]
car_data['Mileage_float'] = car_data['Mileage_float'].apply(pd.to_numeric)
car_data['Power'] = car_data['Power'].apply(pd.to_numeric)
car_data['Power']
car_data['Engine_cc'] = car_data['Engine'].str.split(pat=" ",expand=True)[0].astype(int)

# %% [markdown]
# #### After converting checking the data types again

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7906 entries, 0 to 7905
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales_ID       7906 non-null   int64
#  1   Name           7906 non-null   object
#  2   Year           7906 non-null   int64
#  3   Selling_Price  7906 non-null   int64
#  4   km_Driven      7906 non-null   int64
#  5   City_Code      7906 non-null   object
#  6   State_Code     7906 non-null   object
#  7   Postal_Code    7906 non-null   int64
#  8   Fuel           7906 non-null   object
#  9   Seller_Type    7906 non-null   object
#  10  Transmission   7906 non-null   object
#  11  Owner          7906 non-null   object
#  12  Mileage        7906 non-null   object
#  13  Engine         7906 non-null   object
#  14  Max_Power      7906 non-null   object
#  15  Seats          7906 non-null   int64
#  16  City_Name      7906 non-null   object
#  17  Region_Code    7906 non-null   object
#  18  Sold           7906 non-null   object
#  19  State_Name     7906 non-null   object
#  20  Region         7906 non-null   object
#  21  Mileage_float  7906 non-null   float64
#  22  Power          7906 non-null   float64
#  23  Engine_cc      7906 non-null   int32
# dtypes: float64(2), int32(1), int64(6), object(15)
# memory usage: 1.5+ MB

# %% [markdown]
# ## Check Point 1

# %% [markdown]
# ## Task 1.1(Data Manipulation using Python)

# %% [markdown]
# ### Q1 How the sold cars depend on the Fuel, Mileage, Power and Selling Price.
# ##### We found that Dieseled Cars are having high Power but less Mileage

# %%
car_data.query("Sold =='Y'").groupby(['Sold','Fuel']).agg({'Mileage_float':np.mean,'Power':np.mean}).sort_values(['Fuel'],ascending = False)
# Out:
#              Mileage_float       Power
# Sold Fuel
# Y    Petrol      18.995936   81.794000
#      LPG         21.108333   58.616667
#      Diesel      19.366492  101.923108
#      CNG         25.314286   56.080000

# %% [markdown]
# ##### Then Comapred the Fuel with the Selling Price and Car Driven
# ##### We Concluded that Selling Price of Cars are more which are having more Power and Selling Price of Diseled Car is more.

# %%
car_data.groupby(['Fuel','Sold']).agg({'Mileage_float':np.mean,'Power':np.mean,'km_Driven':np.mean,'Selling_Price':np.mean}).sort_values(['Fuel'],ascending = False)
# Out:
#              Mileage_float       Power     km_Driven  Selling_Price
# Fuel   Sold
# Petrol N         19.113540   79.585652  51883.683946  462360.887814
#        Y         18.995936   81.794000  51532.865241  501153.604278
# LPG    N         18.053448   59.479310  87275.310345  212896.551724
#        Y         21.108333   58.616667  96500.000000  201166.666667
# Diesel N         19.732088  101.451224  83124.325839  791287.744995
#        Y         19.366492  101.923108  83923.622624  836903.476236
# CNG    N         24.281778   61.757333  67459.355556  311022.177778
#        Y         25.314286   56.080000  52142.857143  362142.714286

# %% [markdown]
# ##### Which type of fueled cars are Sold more ?
# ##### If comparing the more number of cars sold are of Diesel but percentage of sold cars is more of Petrol Cars.

# %%
group_column = 'Fuel'
display_name = 'Fuel'
group_df = car_data.groupby([group_column,'Sold'],as_index=False).agg({'Name':'count'})
group_df = group_df.pivot(index=group_column,columns='Sold',values='Name').fillna(0)
group_df['Total'] = group_df['N'] + group_df['Y']
group_df['% Sold'] = ((group_df['Y'] / group_df['Total'])*100).round(2)
group_df.sort_values(by='% Sold',ascending=False, inplace=True)
group_df.reset_index(inplace=True)
group_df.rename(columns={'Y':'Sold',group_column:display_name,'N':'Not Sold'},inplace=True)
display(group_df)
# Out:
# Sold    Fuel  Not Sold  Sold  Total  % Sold
# 0     Petrol      2585   935   3520   26.56
# 1     Diesel      3247  1052   4299   24.47
# 2        LPG        29     6     35   17.14
# 3        CNG        45     7     52   13.46

# %% [markdown]
# ### Q2 How is Fuel related to Brand?

# %% [markdown]
# ##### Extract the brand from the Name of the Cars

# %%
brand = car_data['Name'].str.split(expand = True)
# print(brand)
car_data['Brand'] = brand[0]

# %% [markdown]
# ##### With the below query we tried to extract the brands of which type of Fueled cars are Sold.
# ##### After that we concluded that Sales of the most of the Dieseled cars are more of all the Brands

# %%
car_data.query("Sold == 'Y'").groupby(['Brand','Fuel']).agg({'Fuel':np.size}).rename(columns={'Fuel':'No of sold Cars'})
# Out:
#                       No of sold Cars
# Brand         Fuel
# Audi          Diesel                9
# BMW           Diesel               27
#               Petrol                2
# Chevrolet     Diesel               32
#               Petrol               24
# Daewoo        Petrol                1
# Datsun        Petrol               16
# Fiat          Diesel                6
# Force         Diesel                1
# Ford          Diesel               65
#               Petrol               27
# Honda         Diesel               30
#               Petrol               94
# Hyundai       Diesel              124
#               LPG                   1
#               Petrol              207
# Jaguar        Diesel               21
# Jeep          Diesel                5
#               Petrol                4
# Kia           Diesel                2
# Land          Diesel                1
# Lexus         Petrol               11
# MG            Petrol                2
# Mahindra      Diesel              191
#               Petrol               10
# Maruti        CNG                   7
#               Diesel              201
#               LPG                   5
#               Petrol              384
# Mercedes-Benz Diesel               14
#               Petrol                2
# Mitsubishi    Diesel                3
# Nissan        Diesel               17
#               Petrol               16
# Renault       Diesel               21
#               Petrol               35
# Skoda         Diesel                8
#               Petrol               12
# Tata          Diesel              141
#               Petrol               37
# Toyota        Diesel               88
#               Petrol               38
# Volkswagen    Diesel               27
#               Petrol               12
# Volvo         Diesel               18
#               Petrol                1

# %% [markdown]
# ### Q3 Which brands are selling most?
# ##### Based on the below Query we concluded Maruti Car Brands are sold more

# %%
car_data.query("Sold == 'Y'").groupby(['Brand']).agg({'Sold':np.size}).rename(columns={'Sold':'NoOfCarsSold'}).sort_values(['NoOfCarsSold'],ascending=False)
# Out:
#                NoOfCarsSold
# Brand
# Maruti                  597
# Hyundai                 332
# Mahindra                201
# Tata                    178
# Toyota                  126
# Honda                   124
# Ford                     92
# Chevrolet                56
# Renault                  56
# Volkswagen               39
# Nissan                   33
# BMW                      29
# Jaguar                   21
# Skoda                    20
# Volvo                    19
# Datsun                   16
# Mercedes-Benz            16
# Lexus                    11
# Audi                      9
# Jeep                      9
# Fiat                      6
# Mitsubishi                3
# MG                        2
# Kia                       2
# Force                     1
# Daewoo                    1
# Land                      1

# %% [markdown]
# ##### Further we found most of the Maruti Cars are Sold in Mangalore

# %%
#No of cars sold brandwise on each region by brand

car_data.query("Sold == 'Y' and Brand == 'Maruti'").groupby(['Brand','City_Name'],as_index=False).size().rename(columns={'size':'Total_Sold'}).sort_values('Total_Sold',ascending = False)
# Out:
#      Brand     City_Name  Total_Sold
# 16  Maruti     Mangalore          32
# 6   Maruti      Dehradun          30
# 24  Maruti         Surat          27
# 9   Maruti     Hyderabad          25
# 13  Maruti         Kochi          25
# 27  Maruti       Vellore          24
# 17  Maruti        Mumbai          24
# 18  Maruti        Mysore          23
# 8   Maruti       Gangtok          23
# 20  Maruti         Noida          23
# 7   Maruti         Delhi          22
# 26  Maruti      Vadodara          21
# 4   Maruti       Chennai          21
# 21  Maruti         Patna          20
# 14  Maruti       Kolkata          20
# 23  Maruti        Ranchi          20
# 5   Maruti    Coimbatore          20
# 19  Maruti       Nellore          20
# 25  Maruti      Thrissur          19
# 2   Maruti     Bangalore          19
# 0   Maruti     Ahmedabad          18
# 15  Maruti      Ludhiana          17
# 1   Maruti    Aurangabad          17
# 22  Maruti          Pune          16
# 10  Maruti        Indore          16
# 3   Maruti  Bhubaneshwar          15
# 28  Maruti        kanpur          15
# 11  Maruti        Jaipur          13
# 12  Maruti    Jamshedpur          12

# %% [markdown]
# ##### Compared how the Sold Cars Brands are related to the Selleing Price and which type of brands are sold more comparing individually.

# %%
car_sold = car_data.query("Sold == 'Y'").groupby(['Brand'], as_index=False).agg({'Selling_Price':np.mean,'Sold':np.size}).sort_values(['Selling_Price','Brand'],ascending=False)
car_sold['Total'] = 0
for ind in car_sold.index:
    car_sold['Total'][ind] = car_data[car_data['Brand']==car_sold['Brand'][ind]].shape[0]
car_sold['Percentage'] = (car_sold['Sold']/car_sold['Total'])*100
car_sold['Selling_Price'] = car_sold['Selling_Price']/100000
car_sold.rename(columns={'Selling_Price':'Selling_Price (in lakhs)'}).sort_values('Percentage',ascending=False).reset_index(drop = True)
# Out:
#             Brand  Selling_Price (in lakhs)  Sold  Total  Percentage
# 0              MG                 18.250000     2      3   66.666667
# 1             Kia                 12.715000     2      4   50.000000
# 2          Nissan                  4.209696    33     81   40.740741
# 3          Daewoo                  1.000000     1      3   33.333333
# 4           Lexus                 51.500000    11     34   32.352941
# 5   Mercedes-Benz                 27.671875    16     54   29.629630
# 6          Jaguar                 29.178571    21     71   29.577465
# 7            Jeep                 25.516666     9     31   29.032258
# 8           Volvo                 35.473684    19     67   28.358209
# 9          Toyota                 10.855555   126    452   27.876106
# 10          Honda                  5.825818   124    466   26.609442
# 11       Mahindra                  5.583034   201    758   26.517150
# 12         Maruti                  4.052320   597   2367   25.221800
# 13           Tata                  3.694803   178    719   24.756606
# 14         Datsun                  2.972499    16     65   24.615385
# 15            BMW                 46.065517    29    118   24.576271
# 16        Renault                  4.190357    56    228   24.561404
# 17        Hyundai                  4.632590   332   1360   24.411765
# 18      Chevrolet                  2.795000    56    230   24.347826
# 19           Ford                  5.622282    92    388   23.711340
# 20           Audi                 26.377777     9     40   22.500000
# 21     Mitsubishi                  8.883333     3     14   21.428571
# 22     Volkswagen                  4.924872    39    185   21.081081
# 23          Skoda                  7.477499    20    104   19.230769
# 24          Force                  9.100000     1      6   16.666667
# 25           Land                 45.000000     1      6   16.666667
# 26           Fiat                  3.491667     6     41   14.634146

# %% [markdown]
# ### Q4 Are there specific locations selling more?
# ##### We concluded most of the cars are sold in Mysore individually as well as by comparing the other locations as well

# %%
car_city = car_data.query("Sold == 'Y'").groupby(['Region','State_Name','City_Name']).agg({'Sold':np.size}).sort_values(['Sold'],ascending=False)
car_city['Total'] = 0
car_city['Percentage'] = 0
for index in car_city.index:
    car_city['Total'][index] = car_data[car_data['City_Name'] == index[2]].shape[0]
car_city['Percentage']= (car_city['Sold']/car_city['Total'])*100
car_city.sort_values('Percentage',ascending=False)
# Out:
#                                         Sold  Total  Percentage
# Region     State_Name     City_Name
# South      Karnataka      Mysore          83    279   29.749104
# West       Gujarat        Surat           70    242   28.925620
# South      Tamil Nadu     Vellore         81    293   27.645051
#            Telangana      Hyderabad       72    262   27.480916
#            Karnataka      Mangalore       76    279   27.240143
# Central    Madhya Pradesh Indore          69    257   26.848249
# North East Sikkim         Gangtok         69    257   26.848249
# East       Bihar          Patna           69    257   26.848249
# Central    Uttar Pradesh  Noida           80    303   26.402640
# East       Jharkhand      Jamshedpur      65    247   26.315789
# Central    Uttar Pradesh  kanpur          65    247   26.315789
# South      Tamil Nadu     Coimbatore      77    294   26.190476
# West       Gujarat        Ahmedabad       72    278   25.899281
#            Maharashtra    Mumbai          77    298   25.838926
# East       West Bengal    Kolkata         69    268   25.746269
# North      Punjab         Ludhiana        63    249   25.301205
# South      Tamil Nadu     Chennai         72    285   25.263158
#            Kerala         Thrissur        68    270   25.185185
# East       Odisha         Bhubaneshwar    64    255   25.098039
# Central    Uttarakhand    Dehradun        70    280   25.000000
# North      Delhi          Delhi           80    320   25.000000
# West       Gujarat        Vadodara        66    272   24.264706
# South      Andhra Pradesh Nellore         68    281   24.199288
#            Karnataka      Bangalore       64    276   23.188406
# East       Jharkhand      Ranchi          62    276   22.463768
# South      Kerala         Kochi           62    279   22.222222
# West       Maharashtra    Aurangabad      60    278   21.582734
#                           Pune            52    250   20.800000
# North      Rajasthan      Jaipur          55    274   20.072993

# %% [markdown]
# ### Q5 Which factors which might help in Selling Prices ?

# %% [markdown]
# ##### Type of Owners are also impacting Selling_Price of Cars

# %%
# car_data['Selling_Price'] = car_data['Selling_Price']/100000
car_owner = car_data.groupby(['Owner']).agg({'Selling_Price':(np.mean)}).sort_values(['Selling_Price'],ascending=False)
car_owner['Selling_Price'] = car_owner['Selling_Price']/100000
car_owner.rename(columns = {'Selling_Price':'Selling_Price(in lakhs)'})
# Out:
#                       Selling_Price(in lakhs)
# Owner
# Test Drive Car                      44.038000
# First Owner                          7.899799
# Second Owner                         4.012035
# Third Owner                          2.931873
# Fourth & Above Owner                 2.331968

# %% [markdown]
# ##### with the below query we concluded engine of which range of cars are Sold more

# %%
start = 600
end = 3800
bin_size = 200
bin_count = int((end-start)/bin_size)+1
bin_range = np.linspace(start,end,bin_count)
car_data['Engine_cc_bin'] = pd.cut(car_data['Engine_cc'], bins=bin_range).astype(str)
group_column = 'Engine_cc_bin'
display_name = 'Engine'
slice_df = car_data[(car_data['Selling_Price'].notnull()) & (car_data[group_column].notnull())]
group_df = slice_df.groupby([group_column,'Sold'],as_index=False).agg({'Selling_Price':'mean'})
group_df = group_df.pivot(index=group_column,columns='Sold',values='Selling_Price').fillna(0)
group_df.reset_index(inplace=True)
group_df['Y'] = (group_df['Y']/1000).astype(int)
group_df['N'] = (group_df['N']/1000).astype(int)
group_df.rename(columns={'Y':'Price (k) Sold',group_column:display_name,'N':'Price (k) Not Sold'},inplace=True)
group_df.sort_values(by='Engine',inplace=True)
display(group_df)
# Out:
# Sold            Engine  Price (k) Not Sold  Price (k) Sold
# 0     (1000.0, 1200.0]                 441             455
# 1     (1200.0, 1400.0]                 480             474
# 2     (1400.0, 1600.0]                 569             563
# 3     (1600.0, 1800.0]                 965             761
# 4     (1800.0, 2000.0]                2388            2908
# 5     (2000.0, 2200.0]                 850             847
# 6     (2200.0, 2400.0]                1287             773
# 7     (2400.0, 2600.0]                 955             960
# 8     (2600.0, 2800.0]                1395            1907
# 9     (2800.0, 3000.0]                1939            1923
# 10    (3000.0, 3200.0]                2650            2926
# 11    (3400.0, 3600.0]                1000               0
# 12    (3600.0, 3800.0]                4100            4100
# 13      (600.0, 800.0]                 181             186
# 14     (800.0, 1000.0]                 280             270

# %% [markdown]
# ##### Input Checklist for User based on the Inputs

# %%
paramter_check = ['Brand','Year','Name','Region','State_Name','City_Name','Seller_Type','km_Driven','Fuel','Engine','Seats','Transmission','Owner','Mileage','Max_Power']

km_Driven_range = [0,5000, 10000, 20000, 40000, 80000,160000,200000,250000,np.inf]

names = ['0-5K', '5K-10K', '10K-20K', '20K-40K', '40K-80K','80K-160K','160K-200K','200K-250K','250K+']

car_model_range = [0,1999,2005, 2011, 2015,2018,np.inf]

names_model = ['Antique(upto 1999)', 'Very Old(2000-2005)', 'Old(2006-2011)','Moderate(2012-2015)','Fair(2016-2018)','New(2019+)']

# car_min_selling_price = car_data.copy()
car_min_selling_price = car_data.query("Sold == 'Y'").groupby(paramter_check,as_index=False).agg({'Selling_Price':np.min}).rename(columns={'Selling_Price':'Min_Selling_Price_in_lakhs'}).sort_values(by=['Name','km_Driven'],ascending=[True,True])
car_min_selling_price.Min_Selling_Price_in_lakhs = car_min_selling_price.Min_Selling_Price_in_lakhs/100000

car_min_selling_price['km_Driven_range'] = pd.cut(car_min_selling_price['km_Driven'], km_Driven_range, labels=names)

car_min_selling_price['approx_Mileage'] = car_min_selling_price['Mileage'].str.split(' ', 1).str[0].astype('float64').apply(np.ceil)
# car_min_selling_price
car_min_selling_price['approx_Mileage'] = car_min_selling_price['approx_Mileage'].astype('str')
car_min_selling_price.km_Driven_range = car_min_selling_price.km_Driven_range.astype('object')
# car_min_selling_price.car_model_range = car_min_selling_price.car_model_range.astype('object')

car_min_selling_price['car_model_range'] = pd.cut(car_min_selling_price['Year'], car_model_range, labels=names_model)
# paramter_check = ['Brand','Year','Name','Region','State_Name','City_Name','Seller_Type','km_Driven','Fuel','Engine','Seats','Transmission','Owner','Mileage','Max_Power']
car_min_selling_price.car_model_range = car_min_selling_price.car_model_range.astype('object')


# car_min_selling_price.info()
input_dict = {'Brand':'Maruti','Fuel':'Diesel','approx_Mileage':'25.0'}
# input_check = ['Brand','Year','Name','Seller_Type','km_Driven','Mileage','Max_Power','Fuel','Engine','Seats','Transmission']
input_check = ['Brand','Year','Name','Seller_Type','km_Driven','Mileage','Max_Power','Fuel','Engine','Seats','Transmission','Owner']
#creating dynamic dataframe from the car_min_selling_price dataframe with the user input paramters to display minimum selling price for all brands
car_input_min_selling_price = car_min_selling_price[(car_min_selling_price[''.join(list(input_dict.keys())[0])]==''.join(list(input_dict.values())[0])) & (car_min_selling_price[''.join(list(input_dict.keys())[1])]==''.join(list(input_dict.values())[1])) & (car_min_selling_price[''.join(list(input_dict.keys())[2])]==''.join(list(input_dict.values())[2]))]
pd.pivot_table(car_input_min_selling_price,values=['Min_Selling_Price_in_lakhs'],index =input_check,columns=['car_model_range','km_Driven_range']).head(10).fillna(0).sort_values(by =['Year','Name'],ascending=[True,True])
# Out:
#                                                                                                                                               Min_Selling_Price_in_lakhs  \
# car_model_range                                                                                                                                          Fair(2016-2018)
# km_Driven_range                                                                                                                                                     0-5K
# Brand  Year Name                                    Seller_Type km_Driven Mileage    Max_Power Fuel   Engine  Seats Transmission Owner
# Maruti 2016 Maruti Ertiga SHVS LDI Option           Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       Second Owner                        0.0
#             Maruti Ertiga SHVS VDI                  Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       Second Owner                        0.0
#                                                                 80000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner                         0.0
#             Maruti Ertiga SHVS ZDI Plus             Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner                         0.0
#             Maruti Vitara Brezza VDi                Individual  70000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner                         0.0
#             Maruti Vitara Brezza ZDi Plus           Dealer      63000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner                         0.0
#             Maruti Vitara Brezza ZDi Plus Dual Tone Individual  60000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner                         0.0
#                                                                 90000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner                         0.0
#                                                                 110000    24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       Second Owner                        0.0
#        2017 Maruti Ertiga SHVS VDI                  Individual  80000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner                         0.0
#
#                                                                                                                                                        \
# car_model_range
# km_Driven_range                                                                                                                               10K-20K
# Brand  Year Name                                    Seller_Type km_Driven Mileage    Max_Power Fuel   Engine  Seats Transmission Owner
# Maruti 2016 Maruti Ertiga SHVS LDI Option           Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       Second Owner     0.0
#             Maruti Ertiga SHVS VDI                  Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       Second Owner     0.0
#                                                                 80000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner      0.0
#             Maruti Ertiga SHVS ZDI Plus             Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner      0.0
#             Maruti Vitara Brezza VDi                Individual  70000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner      0.0
#             Maruti Vitara Brezza ZDi Plus           Dealer      63000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner      0.0
#             Maruti Vitara Brezza ZDi Plus Dual Tone Individual  60000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner      0.0
#                                                                 90000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner      0.0
#                                                                 110000    24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       Second Owner     0.0
#        2017 Maruti Ertiga SHVS VDI                  Individual  80000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner      0.0
#
#                                                                                                                                                        \
# car_model_range
# km_Driven_range                                                                                                                               20K-40K
# Brand  Year Name                                    Seller_Type km_Driven Mileage    Max_Power Fuel   Engine  Seats Transmission Owner
# Maruti 2016 Maruti Ertiga SHVS LDI Option           Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       Second Owner     0.0
#             Maruti Ertiga SHVS VDI                  Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       Second Owner     0.0
#                                                                 80000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner      0.0
#             Maruti Ertiga SHVS ZDI Plus             Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner      0.0
#             Maruti Vitara Brezza VDi                Individual  70000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner      0.0
#             Maruti Vitara Brezza ZDi Plus           Dealer      63000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner      0.0
#             Maruti Vitara Brezza ZDi Plus Dual Tone Individual  60000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner      0.0
#                                                                 90000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner      0.0
#                                                                 110000    24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       Second Owner     0.0
#        2017 Maruti Ertiga SHVS VDI                  Individual  80000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner      0.0
#
#                                                                                                                                                        \
# car_model_range
# km_Driven_range                                                                                                                               40K-80K
# Brand  Year Name                                    Seller_Type km_Driven Mileage    Max_Power Fuel   Engine  Seats Transmission Owner
# Maruti 2016 Maruti Ertiga SHVS LDI Option           Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       Second Owner    7.56
#             Maruti Ertiga SHVS VDI                  Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       Second Owner    7.78
#                                                                 80000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner     7.50
#             Maruti Ertiga SHVS ZDI Plus             Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner    10.00
#             Maruti Vitara Brezza VDi                Individual  70000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner     7.45
#             Maruti Vitara Brezza ZDi Plus           Dealer      63000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner     8.39
#             Maruti Vitara Brezza ZDi Plus Dual Tone Individual  60000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner     7.80
#                                                                 90000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner     0.00
#                                                                 110000    24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       Second Owner    0.00
#        2017 Maruti Ertiga SHVS VDI                  Individual  80000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner     7.20
#
#                                                                                                                                                         \
# car_model_range
# km_Driven_range                                                                                                                               80K-160K
# Brand  Year Name                                    Seller_Type km_Driven Mileage    Max_Power Fuel   Engine  Seats Transmission Owner
# Maruti 2016 Maruti Ertiga SHVS LDI Option           Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       Second Owner      0.0
#             Maruti Ertiga SHVS VDI                  Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       Second Owner      0.0
#                                                                 80000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner       0.0
#             Maruti Ertiga SHVS ZDI Plus             Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner       0.0
#             Maruti Vitara Brezza VDi                Individual  70000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner       0.0
#             Maruti Vitara Brezza ZDi Plus           Dealer      63000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner       0.0
#             Maruti Vitara Brezza ZDi Plus Dual Tone Individual  60000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner       0.0
#                                                                 90000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner       8.0
#                                                                 110000    24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       Second Owner      7.0
#        2017 Maruti Ertiga SHVS VDI                  Individual  80000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner       0.0
#
#
# car_model_range                                                                                                                               New(2019+)
# km_Driven_range                                                                                                                                   5K-10K
# Brand  Year Name                                    Seller_Type km_Driven Mileage    Max_Power Fuel   Engine  Seats Transmission Owner
# Maruti 2016 Maruti Ertiga SHVS LDI Option           Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       Second Owner        0.0
#             Maruti Ertiga SHVS VDI                  Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       Second Owner        0.0
#                                                                 80000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner         0.0
#             Maruti Ertiga SHVS ZDI Plus             Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner         0.0
#             Maruti Vitara Brezza VDi                Individual  70000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner         0.0
#             Maruti Vitara Brezza ZDi Plus           Dealer      63000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner         0.0
#             Maruti Vitara Brezza ZDi Plus Dual Tone Individual  60000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner         0.0
#                                                                 90000     24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       First Owner         0.0
#                                                                 110000    24.3 kmpl  88.5 bhp  Diesel 1248 CC 5     Manual       Second Owner        0.0
#        2017 Maruti Ertiga SHVS VDI                  Individual  80000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual       First Owner         0.0

# %% [markdown]
# ## Task 1.3 (Statistical Analysis using Python)

# %% [markdown]
# ### Q1 Descriptive statistics for both numerical and categorical and draw few insights from them.

# %%
car_data.describe(include='all')
# Out:
#            Sales_ID                    Name         Year  Selling_Price  \
# count   7906.000000                    7906  7906.000000   7.906000e+03
# unique          NaN                    1982          NaN            NaN
# top             NaN  Maruti Swift Dzire VDI          NaN            NaN
# freq            NaN                     129          NaN            NaN
# mean    4070.106248                     NaN  2013.983936   6.498137e+05
# std     2345.770159                     NaN     3.863695   8.135827e+05
# min        1.000000                     NaN  1994.000000   2.999900e+04
# 25%     2037.250000                     NaN  2012.000000   2.700000e+05
# 50%     4076.500000                     NaN  2015.000000   4.500000e+05
# 75%     6102.000000                     NaN  2017.000000   6.900000e+05
# max     8128.000000                     NaN  2020.000000   1.000000e+07
#
#            km_Driven City_Code State_Code    Postal_Code    Fuel Seller_Type  \
# count   7.906000e+03      7906       7906    7906.000000    7906        7906
# unique           NaN        29         18            NaN       4           3
# top              NaN      CT09       ST24            NaN  Diesel  Individual
# freq             NaN       320        872            NaN    4299        6563
# mean    6.918866e+04       NaN        NaN  503562.180116     NaN         NaN
# std     5.679230e+04       NaN        NaN  204939.677172     NaN         NaN
# min     1.000000e+00       NaN        NaN  110001.000000     NaN         NaN
# 25%     3.500000e+04       NaN        NaN  391510.000000     NaN         NaN
# 50%     6.000000e+04       NaN        NaN  524225.000000     NaN         NaN
# 75%     9.542500e+04       NaN        NaN  680001.000000     NaN         NaN
# max     2.360457e+06       NaN        NaN  834001.000000     NaN         NaN
#
#         ... City_Name Region_Code  Sold  State_Name Region  Mileage_float  \
# count   ...      7906        7906  7906        7906   7906    7906.000000
# unique  ...        29           6     2          18      6            NaN
# top     ...     Delhi          R4     N  Tamil Nadu  South            NaN
# freq    ...       320        2798  5906         872   2798            NaN
# mean    ...       NaN         NaN   NaN         NaN    NaN      19.419861
# std     ...       NaN         NaN   NaN         NaN    NaN       4.036263
# min     ...       NaN         NaN   NaN         NaN    NaN       0.000000
# 25%     ...       NaN         NaN   NaN         NaN    NaN      16.780000
# 50%     ...       NaN         NaN   NaN         NaN    NaN      19.300000
# 75%     ...       NaN         NaN   NaN         NaN    NaN      22.320000
# max     ...       NaN         NaN   NaN         NaN    NaN      42.000000
#
#               Power    Engine_cc   Brand     Engine_cc_bin
# count   7906.000000  7906.000000    7906              7906
# unique          NaN          NaN      31                15
# top             NaN          NaN  Maruti  (1000.0, 1200.0]
# freq            NaN          NaN    2367              1786
# mean      91.587374  1458.708829     NaN               NaN
# std       35.747216   503.893057     NaN               NaN
# min       32.800000   624.000000     NaN               NaN
# 25%       68.050000  1197.000000     NaN               NaN
# 50%       82.000000  1248.000000     NaN               NaN
# 75%      102.000000  1582.000000     NaN               NaN
# max      400.000000  3604.000000     NaN               NaN
#
# [11 rows x 26 columns]

# %% [markdown]
# ##### How Selling Price of Cars are related with time (Year)
# ##### As per the below query we saw with the increae in th number of sold Cars selling Price of Cars also increased with time.

# %%
car_year = car_data.groupby(['Year']).agg({'Selling_Price':np.mean}).sort_values(['Year'])
car_sold_year = car_data.query("Sold == 'Y'").groupby(['Year']).agg({'Sold':np.size}).sort_values(['Year'])
car_year['Selling_Price_diff'] = 0
car_year['Selling_Price_diff_per'] = 0
prv = car_year['Selling_Price'].head(1)
index = car_year['Selling_Price'].head(1).index
car_year['Selling_Price_diff'][index[0]] = 0
for index in car_year.index:
    car_year['Selling_Price_diff'][index] = float(car_year['Selling_Price'][index])-prv
    prv = car_year['Selling_Price'][index]
    car_year['Selling_Price_diff_per'][index] = (car_year['Selling_Price_diff'][index])/(prv)*100
car_year.sort_values(['Year'],ascending=False)

car_data.query("Sold == 'Y' and Year == index").shape[0]
car_year['Cars_Sold'] = 0
for index in car_year.index:
    if index in car_sold_year.index:
        car_year['Cars_Sold'][index] = car_sold_year['Sold'][index]
car_year['Selling_Price'] = car_year['Selling_Price']/100000
car_year.rename(columns= {'Selling_Price':'Selling_Price(in lakhs)','Selling_Price_diff':'Impact on Selling Price w.r.t previous Year','Selling_Price_diff_per':'% Increase/Decrease in Selling Price'}).sort_values(['Year'],ascending=False)
# Out:
#       Selling_Price(in lakhs)  Impact on Selling Price w.r.t previous Year  \
# Year
# 2020                 8.852702                                      -891716
# 2019                17.769863                                       818802
# 2018                 9.581836                                        67990
# 2017                 8.901930                                       189875
# 2016                 7.003177                                       103547
# 2015                 5.967703                                        80094
# 2014                 5.166757                                        56011
# 2013                 4.606646                                       107521
# 2012                 3.531433                                        31046
# 2011                 3.220964                                        48085
# 2010                 2.740106                                        45201
# 2009                 2.288095                                        23249
# 2008                 2.055598                                        26453
# 2007                 1.791065                                         8644
# 2006                 1.704622                                        26705
# 2005                 1.437566                                        34347
# 2004                 1.094089                                         7836
# 2003                 1.015729                                        -2216
# 2002                 1.037894                                        57289
# 2001                 0.465000                                       -29960
# 2000                 0.764609                                         -467
# 1999                 0.769286                                        19039
# 1998                 0.578889                                       -28222
# 1997                 0.861110                                        45111
# 1996                 0.410000                                       -14000
# 1995                 0.550000                                       -17000
# 1994                 0.720000                                            0
#
#       % Increase/Decrease in Selling Price  Cars_Sold
# Year
# 2020                                  -100         19
# 2019                                    46        154
# 2018                                     7        187
# 2017                                    21        256
# 2016                                    14        225
# 2015                                    13        200
# 2014                                    10        144
# 2013                                    23        174
# 2012                                     8        159
# 2011                                    14        155
# 2010                                    16         96
# 2009                                    10         71
# 2008                                    12         43
# 2007                                     4         28
# 2006                                    15         23
# 2005                                    23         25
# 2004                                     7         13
# 2003                                    -2         10
# 2002                                    55          7
# 2001                                   -64          2
# 2000                                     0          5
# 1999                                    24          3
# 1998                                   -48          0
# 1997                                    52          0
# 1996                                   -34          0
# 1995                                   -30          0
# 1994                                     0          1

# %% [markdown]
# ##### With the increase in time Number of Sold Cars of Automatic Cars also Increasing.

# %%
car_data.query("Sold == 'Y'").groupby(['Year','Transmission']).agg({'Sold':np.size}).rename(columns = {'Sold':'No. of Sold Cars'}).sort_values(['Year','Transmission'],ascending=False)
# Out:
#                    No. of Sold Cars
# Year Transmission
# 2020 Manual                      15
#      Automatic                    4
# 2019 Manual                      79
#      Automatic                   75
# 2018 Manual                     138
#      Automatic                   49
# 2017 Manual                     208
#      Automatic                   48
# 2016 Manual                     183
#      Automatic                   42
# 2015 Manual                     185
#      Automatic                   15
# 2014 Manual                     135
#      Automatic                    9
# 2013 Manual                     160
#      Automatic                   14
# 2012 Manual                     154
#      Automatic                    5
# 2011 Manual                     146
#      Automatic                    9
# 2010 Manual                      91
#      Automatic                    5
# 2009 Manual                      66
#      Automatic                    5
# 2008 Manual                      42
#      Automatic                    1
# 2007 Manual                      26
#      Automatic                    2
# 2006 Manual                      22
#      Automatic                    1
# 2005 Manual                      24
#      Automatic                    1
# 2004 Manual                      12
#      Automatic                    1
# 2003 Manual                      10
# 2002 Manual                       7
# 2001 Manual                       2
# 2000 Manual                       5
# 1999 Manual                       3
# 1994 Manual                       1

# %% [markdown]
# ### Anova Testing

# %%
iv = 'City_Name'
dv = 'Selling_Price'
model = ols(f'{dv} ~ C({iv})', data=car_data[car_data['Sold']=='Y'][[iv,dv]]).fit()
aov_table = sm.stats.anova_lm(model, typ=2) 
display(aov_table)

if aov_table.iloc[0]['PR(>F)'] < .025:
    print(f"We reject the hypothesis that {iv} don't have any impact on Selling Price")
else: 
    print(f"We cannot reject the hypothesis that {iv} don't have any impact on Selling Price")
# Out:
#                     sum_sq      df         F    PR(>F)
# C(City_Name)  2.041014e+13    28.0  0.928303  0.573457
# Residual      1.547694e+15  1971.0       NaN       NaN
# We cannot reject the hypothesis that City_Name don't have any impact on Selling Price

# %%
iv = 'Fuel'
dv = 'Selling_Price'
model = ols(f'{dv} ~ C({iv})', data=car_data[car_data['Sold']=='Y'][[iv,dv]]).fit()
aov_table = sm.stats.anova_lm(model, typ=2) 

if aov_table.iloc[0]['PR(>F)'] < .05:
    print(f"We reject the hypothesis that {iv} don't have any impact on Selling Price")
else: 
    print(f"We cannot reject the hypothesis that {iv} don't have any impact on Selling Price")
# Out:
# We reject the hypothesis that Fuel don't have any impact on Selling Price

# %%
iv = 'Transmission'
dv = 'Selling_Price'
model = ols(f'{dv} ~ C({iv})', data=car_data[car_data['Sold']=='Y'][[iv,dv]]).fit()
aov_table = sm.stats.anova_lm(model, typ=2) 
if aov_table.iloc[0]['PR(>F)'] < .05:
    print(f"We reject the hypothesis that {iv} don't have any impact on Selling Price")
else: 
    print(f"We cannot reject the hypothesis that {iv} don't have any impact on Selling Price")
# Out:
# We reject the hypothesis that Transmission don't have any impact on Selling Price

# %%
iv = 'Owner'
dv = 'Selling_Price'
model = ols(f'{dv} ~ C({iv})', data=car_data[car_data['Sold']=='Y'][[iv,dv]]).fit()
aov_table = sm.stats.anova_lm(model, typ=2) 
# display(aov_table)

if aov_table.iloc[0]['PR(>F)'] < .05:
    print(f"We reject the hypothesis that {iv} don't have any impact on Selling Price")
else: 
    print(f"We cannot reject the hypothesis that {iv} don't have any impact on Selling Price")
# Out:
# We reject the hypothesis that Owner don't have any impact on Selling Price

# %%
iv = 'Year'
dv = 'Selling_Price'
model = ols(f'{dv} ~ C({iv})', data=car_data[car_data['Sold']=='Y'][[iv,dv]]).fit()
aov_table = sm.stats.anova_lm(model, typ=2) 
# display(aov_table)

if aov_table.iloc[0]['PR(>F)'] < .05:
    print(f"We reject the hypothesis that {iv} don't have any impact on Selling Price")
else: 
    print(f"We cannot reject the hypothesis that {iv} don't have any impact on Selling Price")
# Out:
# We reject the hypothesis that Year don't have any impact on Selling Price

# %% [markdown]
# # CheckPoint 2
# ###### Task 2.1

# %%
car_data.columns
# Out:
# Index(['Sales_ID', 'Name', 'Year', 'Selling_Price', 'km_Driven', 'City_Code',
#        'State_Code', 'Postal_Code', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Mileage', 'Engine', 'Max_Power', 'Seats', 'City_Name',
#        'Region_Code', 'Sold', 'State_Name', 'Region', 'Mileage_float', 'Power',
#        'Engine_cc', 'Brand', 'Engine_cc_bin'],
#       dtype='object')

# %%
car_data_graphs = car_data.drop(['Sales_ID','Postal_Code'],axis = 1)
# pd.get_dummies(car_data_graphs['Fuel'])
car_data_graphs.corr()
# Out:
#                    Year  Selling_Price  km_Driven     Seats  Mileage_float  \
# Year           1.000000       0.412302  -0.428548 -0.007923       0.328544
# Selling_Price  0.412302       1.000000  -0.222158  0.041617      -0.126280
# km_Driven     -0.428548      -0.222158   1.000000  0.227259      -0.172980
# Seats         -0.007923       0.041617   0.227259  1.000000      -0.451700
# Mileage_float  0.328544      -0.126280  -0.172980 -0.451700       1.000000
# Power          0.226598       0.749674  -0.038159  0.191999      -0.374621
# Engine_cc      0.018263       0.455682   0.206031  0.611103      -0.576408
#
#                   Power  Engine_cc
# Year           0.226598   0.018263
# Selling_Price  0.749674   0.455682
# km_Driven     -0.038159   0.206031
# Seats          0.191999   0.611103
# Mileage_float -0.374621  -0.576408
# Power          1.000000   0.703975
# Engine_cc      0.703975   1.000000

# %%
# sn.heatmap(car_data_graphs.corr(), annot = True)
#Correlation for numerical fields
plt.figure(figsize=(10,8))
sns.heatmap(car_data_graphs.corr(), annot=True, cmap="summer", vmin=0, vmax=1)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.scatter(car_data_graphs['Power'], car_data_graphs['Selling_Price'], color = "purple")
plt.title('Scatterplot of Power of Car vs Price')
plt.xlabel('Power')
plt.ylabel('Price')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.scatter(car_data_graphs['Power'], car_data_graphs['Engine_cc'],color = "purple")
plt.title('Scatterplot of Power of Car vs Engine')
plt.xlabel('Power')
plt.ylabel('Engine in cc')
plt.grid()
plt.show()

# %%
#TOP 10 most Selling Brands
cbrand=pd.DataFrame(car_data[car_data['Sold']=='Y'][['Brand']].value_counts().head(10),columns=['Count'])
cbrand.reset_index(inplace=True)
plt.figure(figsize=(10,10))
# sns.color_palette("pink")
sns.barplot(x='Count',y='Brand',data=cbrand, palette='pastel')
plt.title('TOP 10 most Selling Brands',fontsize=25)
# Out:
# Text(0.5, 1.0, 'TOP 10 most Selling Brands')

# %%
#count of sold cars among states
plt.figure(figsize=(30,5))
p =sns.countplot(x='City_Name',data=car_data[car_data['Sold']=='Y'])
# show_values(p)
plt.xlabel('City_Name',fontsize=25)
plt.ylabel('Car_Count',fontsize=25)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.title('Count of sold cars among Cities',fontsize=20)

# figure.tight_layout()
# Out:
# Text(0.5, 1.0, 'Count of sold cars among Cities')

# %%
# fig,axes=plt.subplots(nrows=2,ncols=2,figsize=(20,10))
# axes[0,0].scatter(x='Fuel',y='Selling_Price',data=car_data[car_data['Sold']=='Y'],color='green')
# axes[0,0].set_xlabel('Fuel_Type')
# axes[0,0].set_ylabel('Selling_Price')
# axes[0,0].set_title('Fuel_Type Vs Selling_Price',fontsize=20)

# sns.barplot(x=car_data_vis['Fuel'],y=car_data_vis['SP_in_Lakhs'],hue=car_data_vis['Seller_Type'],data=car_data_vis.query("Sold=='Y'"))
# plt.title('Selling Price for Different Fuel Type w.r.t Seller_Type')
# axes[0,1].scatter(x='Transmission',y='Selling_Price',data=car_data[car_data['Sold']=='Y'],color='blue')
# axes[0,1].set_xlabel('Transmission')
# axes[0,1].set_ylabel('Selling_Price')
# axes[0,1].set_title('Transmission Vs Selling_Price',fontsize=20)

# axes[1,0].scatter(x='Owner',y='Selling_Price',data=car_data[car_data['Sold']=='Y'],color='red')
# axes[1,0].set_xlabel('Owner')
# axes[1,0].set_ylabel('Selling_Price')
# axes[1,0].set_title('Owner Vs Selling_Price',fontsize=20)

# axes[1,1].scatter(x='Year',y='Selling_Price',data=car_data[car_data['Sold']=='Y'],color='purple')
# axes[1,1].set_xlabel('year')
# axes[1,1].set_ylabel('Selling_Price')
# axes[1,1].set_title('Year Vs Selling_Price',fontsize=20)

# fig.tight_layout()
# sns.color_palette("pastel")
plt.figure(figsize=(20,5))
sns.barplot(x=car_data['Fuel'],y=car_data['Selling_Price'],hue=car_data['Owner'],data=car_data.query("Sold=='Y'"),palette='pastel')
plt.title('Selling Price for Different Fuel Type w.r.t Owner')
plt.show()

plt.figure(figsize=(20,5))
sns.barplot(x=car_data['Fuel'],y=car_data['Selling_Price'],hue=car_data['Seller_Type'],data=car_data.query("Sold=='Y'"),palette='pastel')
plt.title('Selling Price for Different Fuel Type w.r.t Seller_Type')
plt.show()

plt.figure(figsize=(20,5))
sns.barplot(x=car_data['Fuel'],y=car_data['Selling_Price'],hue=car_data['Transmission'],data=car_data.query("Sold=='Y'"),palette='pastel')
plt.title('Selling Price for Different Fuel Type w.r.t Transmission')
plt.show()

# %%
#No of cars sold per year
plt.figure(figsize=(15,8))
df = car_data.query("Sold == 'Y'").groupby('Year').agg({'Selling_Price':np.mean})
sns.barplot(x=df.index, y="Selling_Price", data=df)
# # car_data[car_data['Sold']=='Y']['Year'].value_counts().plot(kind='bar',color = '#ff9999')
plt.ylabel("Avg Selling Price")
plt.title("Avg Selling Price per year",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Avg Selling Price per year')

# %%
#Univarient

# %%
style.use('fivethirtyeight')
plt.figure(figsize=(15,5))
sns.distplot(car_data['Selling_Price'],bins=50,kde=False,color = 'purple')
# Out:
# C:\Users\lbansal\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Selling_Price'>

# %%
car_data['Selling_Price'].plot(kind = 'density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#No of cars sold per year
plt.figure(figsize=(15,8))
df = car_data.query("Sold == 'Y'").groupby('Year').agg({'Year':np.size})
sns.barplot(x=df.index, y="Year", data=df)
# # car_data[car_data['Sold']=='Y']['Year'].value_counts().plot(kind='bar',color = '#ff9999')
plt.ylabel("No of Cars Sold")
plt.title("No of cars solds per year",fontsize=20)
# Out:
# Text(0.5, 1.0, 'No of cars solds per year')

# %%
fig,axes=plt.subplots(nrows=2,ncols=2,figsize=(20,10))
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
axes[0,0].pie(car_data[car_data['Sold']=='Y']['Fuel'].value_counts().values,labels = car_data[car_data['Sold']=='Y']['Fuel'].value_counts().index, autopct='%1.2f%%', explode = [0,0,0.5,0.8], colors = colors)
# axes[0,0].set_xlabel('Fuel_Type')
# axes[0,0].set_ylabel('Count')
# axes[0,0].set_title('Fuel_Type Vs Car Count',fontsize=20)

axes[0,1].pie(car_data[car_data['Sold']=='Y']['Transmission'].value_counts().values,labels = car_data[car_data['Sold']=='Y']['Transmission'].value_counts().index, autopct='%1.2f%%',  colors = colors)
# axes[0,1].set_xlabel('Transmission')
# axes[0,1].set_ylabel('Count')
# axes[0,1].set_title('Fuel_Type Vs Car Count',fontsize=20)

# axes[0,1].bar(car_data[car_data['Sold']=='Y']['Transmission'].value_counts().index,car_data[car_data['Sold']=='Y']['Transmission'].value_counts().values,color='blue')
# axes[0,1].set_xlabel('Transmission')
# axes[0,1].set_ylabel('Count')
# axes[0,1].set_title('Transmission Vs Car Count',fontsize=20)
axes[1,0].pie(car_data[car_data['Sold']=='Y']['Owner'].value_counts().values,labels = car_data[car_data['Sold']=='Y']['Owner'].value_counts().index, autopct='%1.2f%%',  colors = colors)

# axes[1,0].bar(car_data[car_data['Sold']=='Y']['Owner'].value_counts().index,car_data[car_data['Sold']=='Y']['Owner'].value_counts().values,color='red')
# axes[1,0].set_xlabel('Owner')
# axes[1,0].set_ylabel('Count')
# axes[1,0].set_title('Owner Vs Car Count',fontsize=20)
axes[1,1].pie(car_data[car_data['Sold']=='Y']['Seats'].value_counts().values,labels = car_data[car_data['Sold']=='Y']['Seats'].value_counts().index, autopct='%1.2f%%',   colors = colors, explode = [0,0,0.5,0.8,0.6,0.7,0.9])

# axes[1,1].bar(car_data[car_data['Sold']=='Y']['Seats'].value_counts().index,car_data[car_data['Sold']=='Y']['Seats'].value_counts().values,color='purple')
# axes[1,1].set_xlabel('Seats')
# axes[1,1].set_ylabel('Count')
# axes[1,1].set_title('Seats Vs Car Count',fontsize=20)
# colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
# plt.pie(car_data[car_data['Sold']=='Y']['Fuel'].value_counts(),labels=Fuel_data.index,autopct='%1.2f%%', explode = [0,0,0.5,0.8], colors = colors )
# plt.title('Percentage of cars sold based on fuel type',fontsize=15)

fig.tight_layout()

# %%
plt.figure(figsize=(40,10))
sns.barplot(x='Brand',y='Selling_Price',data=car_data[car_data['Sold']=='Y'],estimator=np.mean,ci=None)
plt.xlabel('Brand',fontsize=25)
plt.ylabel('Selling_Price',fontsize=25)
plt.xticks(fontsize=12)
plt.yticks(fontsize=15)
fig.tight_layout()

# %%
pd.options.display.float_format = '{1.2f}'.format
plt.figure(figsize = (15,5)) 
df = car_data.groupby('Brand').agg({'Selling_Price':np.mean})
df['Selling_Price'] = round(df['Selling_Price']/100000,2)
plt.bar(df.index, df['Selling_Price'],color= 'pink')
# plt.title("Top 20 with higest Average Selling Price", fontsize=18)
plt.xlabel("Brand",fontsize=15) 
plt.ylabel("Average Selling Price",fontsize=15) 
plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)
tuple=sorted(df["Selling_Price"].items(),key=lambda x:x[1])
# print(list(tuple))
for k,v in df["Selling_Price"].items():
    if v>25:
        plt.text(k,v-25, str(v) + ' lac.', fontsize=12,rotation=90,color='k', horizontalalignment='center')
    else:
        plt.text(k,v+2,str(v) + ' lac.', fontsize=12,rotation=90,color='k', horizontalalignment='center')

# %%
sns.pairplot(car_data_graphs.query("Sold=='Y'"),hue='Seller_Type')

# %%
sns.pairplot(car_data_graphs.query("Sold=='Y'"),hue='Fuel')

# %%
car_data.isnull().sum()
# Out:
# Sales_ID         0
# Name             0
# Year             0
# Selling_Price    0
# km_Driven        0
# City_Code        0
# State_Code       0
# Postal_Code      0
# Fuel             0
# Seller_Type      0
# Transmission     0
# Owner            0
# Mileage          0
# Engine           0
# Max_Power        0
# Seats            0
# City_Name        0
# Region_Code      0
# Sold             0
# State_Name       0
# Region           0
# Mileage_float    0
# Power            0
# Engine_cc        0
# Brand            0
# Engine_cc_bin    0
# dtype: int64

# %%
sns.boxplot(car_data.query("Sold == 'Y'")['Selling_Price'],palette = 'pastel')
# Out:
# C:\Users\lbansal\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Selling_Price'>

# %%
car_data['Selling_Price'].quantile(0.99)
# Out:
# 5200000.0

# %%
car_data.plot(kind = 'box', subplots = True, layout = (3,3))
# Out:
# Sales_ID             AxesSubplot(0.08,0.641765;0.255882x0.238235)
# Year             AxesSubplot(0.387059,0.641765;0.255882x0.238235)
# Selling_Price    AxesSubplot(0.694118,0.641765;0.255882x0.238235)
# km_Driven            AxesSubplot(0.08,0.355882;0.255882x0.238235)
# Postal_Code      AxesSubplot(0.387059,0.355882;0.255882x0.238235)
# Seats            AxesSubplot(0.694118,0.355882;0.255882x0.238235)
# Mileage_float            AxesSubplot(0.08,0.07;0.255882x0.238235)
# Power                AxesSubplot(0.387059,0.07;0.255882x0.238235)
# Engine_cc            AxesSubplot(0.694118,0.07;0.255882x0.238235)
# dtype: object

# %%
# sns.boxplot(car_data.all(), palette = 'pastel')
bp = plt.boxplot(car_data['Selling_Price'])
bp
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e752e81850>,
#   <matplotlib.lines.Line2D at 0x1e752e81be0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e752e81f70>,
#   <matplotlib.lines.Line2D at 0x1e752e8d340>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e752e814c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e752e8d6d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e752e8da90>],
#  'means': []}

# %%
a = bp['fliers'][0]
a.get_data()[1]
# Out:
# array([ 2100000,  1500000,  1450000,  1650000,  1750000,  1590000,
#         1689999,  1425000,  1700000,  2500000,  1700000,  3975000,
#         5150000,  3200000,  4100000,  4500000,  6000000,  3790000,
#         5800000,  1864999,  2700000,  1750000,  3400000,  2650000,
#         5850000,  2625000,  2550000,  2700000,  1525000,  2150000,
#         1900000,  2900000, 10000000,  1750000,  1380000,  4600000,
#         3000000,  1550000,  2625000,  5150000,  3200000,  3800000,
#         2000000,  5400000,  5500000,  2475000,  2625000,  5150000,
#         3200000,  3800000,  2000000,  5400000,  5500000,  2475000,
#         1525000,  2000000,  1900000,  1600000,  1800000,  1650000,
#         1350000,  1500000,  2625000,  5150000,  3200000,  3800000,
#         2000000,  5400000,  5500000,  2475000,  3000000,  1625000,
#         1600000,  1745000,  1325000,  1380000,  3750000,  2900000,
#         1400000,  1450000,  2700000,  1925000,  1900000,  6000000,
#         2940000,  1825000,  2625000,  5150000,  3200000,  3800000,
#         2000000,  5400000,  5500000,  2475000,  2625000,  5150000,
#         3200000,  3800000,  2000000,  5400000,  5500000,  2475000,
#         2625000,  5150000,  3200000,  3800000,  2000000,  5400000,
#         5500000,  2475000,  2625000,  5150000,  3200000,  3800000,
#         2000000,  5400000,  5500000,  2475000,  1400000,  1576000,
#         1560000,  1950000,  3250000,  2900000,  3975000,  5150000,
#         3200000,  4100000,  2000000,  1575000,  1575000,  1465000,
#         1350000,  1700000,  1460000,  2625000,  5150000,  3200000,
#         3800000,  2000000,  5400000,  5500000,  2475000,  2950000,
#         1325000,  1675000,  3200000,  3800000,  3250000,  3200000,
#         1400000,  3975000,  5150000,  3200000,  4100000,  2000000,
#         5400000,  5500000,  1888000,  2280000,  2450000,  2825000,
#         2125000,  3350000,  1800000,  1950000,  1900000,  2950000,
#         3200000,  2600000,  1594000,  1689999,  1530000,  2600000,
#         1850000,  3000000,  1850000,  1650000,  1350000,  1325000,
#         1700000,  1575000,  1500000,  2625000,  5150000,  3200000,
#         3800000,  2000000,  5400000,  5500000,  2475000,  1850000,
#         2625000,  5150000,  3200000,  3800000,  2000000,  5400000,
#         5500000,  2475000,  1500000,  2199000,  3600000,  1325000,
#         1650000,  2000000,  2850000,  2800000,  3900000,  1450000,
#         1950000,  1800000,  2900000,  1700000,  7200000,  1670000,
#         1350000,  2625000,  5150000,  3200000,  3800000,  2000000,
#         5400000,  5500000,  2475000,  1750000,  1390000,  1350000,
#         2100000,  3975000,  5150000,  3200000,  4100000,  4500000,
#         3790000,  1750000,  1864999,  1825000,  4090000,  3400000,
#         2600000,  1850000,  1475000,  1475000,  1630000,  2711000,
#         5150000,  3200000,  3800000,  2000000,  5400000,  5500000,
#         2475000,  1575000,  2711000,  5150000,  3200000,  3800000,
#         2000000,  5400000,  5500000,  2475000,  1700000,  1700000,
#         1550000,  1511000,  1650000,  1575000,  1500000,  1500000,
#         1800000,  2711000,  5150000,  3200000,  3800000,  2000000,
#         5400000,  5500000,  2475000,  2000000,  1515000,  1460000,
#         2000000,  1750000,  2100000,  1350000,  3750000,  2900000,
#         1400000,  1450000,  2700000,  1925000,  1900000,  6000000,
#         1405000,  1500000,  1500000,  1460000,  2700000,  1700000,
#         2711000,  5150000,  3200000,  3800000,  2000000,  5400000,
#         5500000,  2475000,  2711000,  5150000,  3200000,  3800000,
#         2000000,  5400000,  5500000,  2475000,  2711000,  5150000,
#         3200000,  3800000,  2000000,  5400000,  5500000,  2475000,
#         2711000,  5150000,  3200000,  3800000,  2000000,  5400000,
#         5500000,  2475000,  2450000,  3100000,  2600000,  1850000,
#         1600000,  1350000,  1950000,  1600000,  2700000,  1920000,
#         2711000,  5150000,  3200000,  3800000,  2000000,  5400000,
#         5500000,  2475000,  1365000,  1490000,  1350000,  1700000,
#         1680000,  2950000,  5200000,  1650000,  2375000,  2150000,
#         2750000,  2900000,  1465000,  1385000,  2000000,  2600000,
#         1850000,  5500000,  2950000,  1925000,  1650000,  6000000,
#         2700000,  2711000,  1675000,  2500000,  2550000,  2700000,
#         1748999,  1525000,  2150000,  2711000,  5150000,  3200000,
#         3800000,  2000000,  5400000,  5500000,  2475000,  2064000,
#         1850000,  1900000,  1650000,  6223000,  5923000,  6523000,
#         2500000,  1800000,  1757000,  2711000,  5150000,  3200000,
#         3800000,  2000000,  5400000,  5500000,  2475000,  2000000,
#         2500000,  3200000,  3975000,  5150000,  3200000,  4100000,
#         2000000,  5400000,  5500000,  2475000,  5200000,  4500000,
#         6000000,  4000000,  1898999,  1650000,  1400000,  1800000,
#         1525000,  1700000,  1550000,  1450000,  1925000,  3251000,
#         2000000,  1500000,  2711000,  5150000,  3200000,  3800000,
#         2000000,  5400000,  5500000,  2475000,  3200000,  2000000,
#         1938000,  3500000,  1550000,  1900000,  1650000,  1500000,
#         2000000,  3100000,  1500000,  1800000,  2100000,  1350000,
#         1350000,  2711000,  5150000,  3200000,  3800000,  2000000,
#         5400000,  5500000,  2475000,  3800000,  3200000,  3500000,
#         2000000,  1350000,  1525000,  5830000,  1650000,  1450000,
#         1750000,  1650000,  1500000,  1400000,  1700000,  2400000,
#         3000000,  3200000,  2711000,  5150000,  3200000,  3800000,
#         2000000,  5400000,  5500000,  2475000,  2711000,  5150000,
#         3200000,  3800000,  2000000,  5400000,  5500000,  2475000,
#         2300000,  2200000,  2711000,  5150000,  3200000,  3800000,
#         2000000,  5400000,  5500000,  2475000,  1850000,  2000000,
#         1750000,  1630000,  1350000,  1520000,  1350000,  2711000,
#         5150000,  3200000,  3800000,  2000000,  5400000,  5500000,
#         2475000,  1600000,  1500000,  1680000,  1950000,  3000000,
#         1500000,  1450000,  1445000,  2000000,  1380000,  2825000,
#         2125000,  3350000,  1800000,  3300000,  4600000,  5800000,
#         1450000,  1789999,  2450000,  2000000,  1650000,  1859000,
#         1550000,  1550000,  3250000,  2200000,  5500000,  2175000,
#         1650000,  5830000,  3200000,  3975000,  1350000,  5150000,
#         3200000,  4100000,  2000000,  4000000,  5200000,  4500000,
#         6000000,  1650000,  2100000,  1500000,  1380000,  2950000,
#         5200000,  1405000,  1850000,  1750000,  2051000,  2575000,
#         1380000,  2711000,  5150000,  3200000,  3800000,  2000000,
#         5400000,  5500000,  2475000,  1689999,  1516000,  1600000,
#         1400000,  2800000,  1850000,  5500000,  2100000,  1400000,
#         1500000,  1400000,  1689999,  1575000], dtype=int64)

# %%
np.min(a.get_data()[1])
# Out:
# 1325000

# %%
# car_data.query('Selling_Price < 5200000', inplace = True)
# car_data[(car_data['Selling_Price'] < 5200000)]
# car_data[car_data['Selling_Price'] < 5200000]
# car_data.info()
# d
upper_limit = 5200000
car_data_1 = car_data[car_data['Selling_Price'] < upper_limit]
car_data_2 = car_data[car_data['Selling_Price'] >= upper_limit]
car_data_1 = car_data_1[car_data_1['Sold'] == 'Y']
car_data_2 = car_data_2[car_data_2['Sold'] == 'Y']

# car_data_1 = car_data.copy()
# car_data_1['Selling_Price'] = np.where(
#     car_data_1['Selling_Price'] > upper_limit,
#     upper_limit,
#     np.where(
#         car_data_1['Selling_Price'] < lower_limit,
#         lower_limit,
#         car_data_1['Selling_Price']
#     )
# )

# %%
car_data_1.shape
# Out:
# (1977, 26)

# %%
car_data_1['Brand'].unique()
# Out:
# array(['Maruti', 'Skoda', 'Honda', 'Hyundai', 'Toyota', 'Ford', 'Renault',
#        'Mahindra', 'Tata', 'Chevrolet', 'Datsun', 'Jeep', 'Mercedes-Benz',
#        'Mitsubishi', 'Audi', 'Volkswagen', 'BMW', 'Nissan', 'Lexus',
#        'Jaguar', 'Land', 'MG', 'Volvo', 'Daewoo', 'Kia', 'Fiat', 'Force'],
#       dtype=object)

# %%
car_data_2.shape
# Out:
# (23, 26)

# %%
car_data.query("Sold == 'Y'").shape
# Out:
# (2000, 26)

# %%
car_data_1.query("Sold == 'Y'").shape
# Out:
# (1977, 26)

# %%
sns.boxplot(car_data_1.query("Sold == 'Y'")['Selling_Price'],palette = 'pastel')
# Out:
# C:\Users\lbansal\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Selling_Price'>

# %%
car_data_1.columns
# Out:
# Index(['Sales_ID', 'Name', 'Year', 'Selling_Price', 'km_Driven', 'City_Code',
#        'State_Code', 'Postal_Code', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Mileage', 'Engine', 'Max_Power', 'Seats', 'City_Name',
#        'Region_Code', 'Sold', 'State_Name', 'Region', 'Mileage_float', 'Power',
#        'Engine_cc', 'Brand', 'Engine_cc_bin'],
#       dtype='object')

# %%
car_data_m = car_data_1.drop(columns=['Sales_ID','Max_Power','City_Code','State_Code','Postal_Code','Region_Code','Sold','State_Name','Engine_cc_bin','Mileage','Engine','Region'])
car_data_m.columns
# Out:
# Index(['Name', 'Year', 'Selling_Price', 'km_Driven', 'Fuel', 'Seller_Type',
#        'Transmission', 'Owner', 'Seats', 'City_Name', 'Mileage_float', 'Power',
#        'Engine_cc', 'Brand'],
#       dtype='object')

# %%
X = car_data_m.drop(columns='Selling_Price').copy()
y = car_data_m['Selling_Price'].copy()
X.columns
# Out:
# Index(['Name', 'Year', 'km_Driven', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Seats', 'City_Name', 'Mileage_float', 'Power', 'Engine_cc',
#        'Brand'],
#       dtype='object')

# %%
# we will start with simple linear regression with independent variable as Engine Size
# save arrays in variables X_lr and y_lr
X_lr = np.array(car_data_m['Power'])
y_lr = np.array(car_data_m['Selling_Price'])

# %%
# plot the dependent and independent vriable on a scatter plot
plt.scatter(X_lr,y_lr)

# %%
# model a linear regression using sklearn
# define an object for linear regression model
lr =LinearRegression()

# fit the linear regresion model for give data
lr.fit(X_lr.reshape(-1,1),y_lr)

# print the intercept and the coefficients
print("The intercept of the Lienar Regression model is: ", lr.intercept_)
print("The coefficient of the Linear Regression model is: ",lr.coef_)
# Out:
# The intercept of the Lienar Regression model is:  -776402.2811714576
# The coefficient of the Linear Regression model is:  [15341.75577877]

# %%
# calculate the predicted value using the above equation
y_pred = lr.intercept_ + lr.coef_*X_lr
y_pred
# Out:
# array([358887.64645754, 811776.27704684, 420254.66957262, ...,
#        -50737.23283562, 585331.96175219, 806866.91519764])

# %%
# plot a scatter plot alogn with the regression line
plt.scatter(X_lr,y_lr)
plt.plot(X_lr,y_pred,color='r')

# %%
# calculate the evaluation metrics of R2 score and Mean Squared Error

print("R2 Score of linear regression model is:", r2_score(y_lr, y_pred))
print("Mean Squared Error of linear regression model is: ", mean_squared_error(y_lr, y_pred))
# Out:
# R2 Score of linear regression model is: 0.5841862607573785
# Mean Squared Error of linear regression model is:  200739857614.549

# %%
X.columns
# Out:
# Index(['Name', 'Year', 'km_Driven', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Seats', 'City_Name', 'Mileage_float', 'Power', 'Engine_cc',
#        'Brand'],
#       dtype='object')

# %%
X = car_data_m.drop(columns='Selling_Price').copy()
car_data_multi_val = pd.get_dummies(X[['Fuel','Seller_Type','Transmission','Owner']])
car_data_multi_val

# concat the ohe_fuel dummies with original dataframe X
X = pd.concat([X,car_data_multi_val], axis=1)


# drop the column Fuel Type from original dataframe X
X.drop(columns=['Fuel','Seller_Type','Transmission','Owner','City_Name','Name','Brand'],inplace=True)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1977 entries, 0 to 1999
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          1977 non-null   int64
#  1   km_Driven                     1977 non-null   int64
#  2   Seats                         1977 non-null   int64
#  3   Mileage_float                 1977 non-null   float64
#  4   Power                         1977 non-null   float64
#  5   Engine_cc                     1977 non-null   int32
#  6   Fuel_CNG                      1977 non-null   uint8
#  7   Fuel_Diesel                   1977 non-null   uint8
#  8   Fuel_LPG                      1977 non-null   uint8
#  9   Fuel_Petrol                   1977 non-null   uint8
#  10  Seller_Type_Dealer            1977 non-null   uint8
#  11  Seller_Type_Individual        1977 non-null   uint8
#  12  Seller_Type_Trustmark Dealer  1977 non-null   uint8
#  13  Transmission_Automatic        1977 non-null   uint8
#  14  Transmission_Manual           1977 non-null   uint8
#  15  Owner_First Owner             1977 non-null   uint8
#  16  Owner_Fourth & Above Owner    1977 non-null   uint8
#  17  Owner_Second Owner            1977 non-null   uint8
#  18  Owner_Third Owner             1977 non-null   uint8
# dtypes: float64(2), int32(1), int64(3), uint8(13)
# memory usage: 125.5 KB

# %%
# fit the linear regression and predict the values
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
# print the intercept and the coefficients of the model
print("Intercept for linear regression model is: ", round(lr.intercept_,3))
print("Coefficients for linear regression model are: ", np.round(lr.coef_,decimals=3))
# Out:
# Intercept for linear regression model is:  -56394184.536
# Coefficients for linear regression model are:  [ 2.75715500e+04 -1.19500000e+00 -2.17616620e+04  2.67381160e+04
#   1.12348930e+04  2.32088000e+02 -3.97346200e+04 -6.00961940e+04
#   1.33392573e+05 -3.35617600e+04  1.46021673e+05 -2.67531840e+04
#  -1.19268488e+05  1.86247299e+05 -1.86247299e+05  1.38089820e+04
#   4.58238730e+04 -2.74066290e+04 -3.22262250e+04]

# %%
# predict the values using liner regression
y_pred = lr.predict(X)

# %%
# plt.scatter(X,y)
# plt.plot(X,y_pred,color='r')
# print(X.shape)
# print(y.shape)
# print(y_pred.shape)

# %%
# calculate the r2 score of the model
print("R2 score for the linear regression model is:", r2_score(y,y_pred))
# Out:
# R2 score for the linear regression model is: 0.7186003201844197

# %%
# import the required sklearn module
from sklearn.model_selection import train_test_split

# split the data in train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2)
print(X.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (1977, 19)
# (1581, 19)
# (396, 19)

# %%
# fit the linear regression model on training dataset
lr = LinearRegression()
lr.fit(X_train,y_train)
print("Intercept: ",lr.intercept_)
print("Coefficients: ",lr.coef_)
# Out:
# Intercept:  -56310140.24875016
# Coefficients:  [ 2.75592089e+04 -1.11795420e+00 -1.86947703e+04  2.55793378e+04
#   1.07518253e+04  2.34588494e+02 -5.38850917e+04 -6.89634051e+04
#   1.79162128e+05 -5.63136313e+04  1.41722271e+05 -4.15323329e+04
#  -1.00189938e+05  1.78379620e+05 -1.78379620e+05  1.34952461e+04
#   4.84953482e+04 -3.78197863e+04 -2.41708080e+04]

# %%
# predict the values from model on test set
y_pred = lr.predict(X_test)

# evaluate the model using R2 score
print("R2 Score: ", r2_score(y_test, y_pred))
# Out:
# R2 Score:  0.7597205337467263

# %%
X = car_data_m.drop(columns='Selling_Price').copy()
car_data_multi_val = pd.get_dummies(X[['Fuel','Seller_Type','Transmission','Owner','Brand']])
car_data_multi_val

# concat the ohe_fuel dummies with original dataframe X
X = pd.concat([X,car_data_multi_val], axis=1)


# drop the column Fuel Type from original dataframe X
X.drop(columns=['Fuel','Seller_Type','Transmission','Owner','City_Name','Name','Brand','Seats'],inplace=True)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1977 entries, 0 to 1999
# Data columns (total 45 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          1977 non-null   int64
#  1   km_Driven                     1977 non-null   int64
#  2   Mileage_float                 1977 non-null   float64
#  3   Power                         1977 non-null   float64
#  4   Engine_cc                     1977 non-null   int32
#  5   Fuel_CNG                      1977 non-null   uint8
#  6   Fuel_Diesel                   1977 non-null   uint8
#  7   Fuel_LPG                      1977 non-null   uint8
#  8   Fuel_Petrol                   1977 non-null   uint8
#  9   Seller_Type_Dealer            1977 non-null   uint8
#  10  Seller_Type_Individual        1977 non-null   uint8
#  11  Seller_Type_Trustmark Dealer  1977 non-null   uint8
#  12  Transmission_Automatic        1977 non-null   uint8
#  13  Transmission_Manual           1977 non-null   uint8
#  14  Owner_First Owner             1977 non-null   uint8
#  15  Owner_Fourth & Above Owner    1977 non-null   uint8
#  16  Owner_Second Owner            1977 non-null   uint8
#  17  Owner_Third Owner             1977 non-null   uint8
#  18  Brand_Audi                    1977 non-null   uint8
#  19  Brand_BMW                     1977 non-null   uint8
#  20  Brand_Chevrolet               1977 non-null   uint8
#  21  Brand_Daewoo                  1977 non-null   uint8
#  22  Brand_Datsun                  1977 non-null   uint8
#  23  Brand_Fiat                    1977 non-null   uint8
#  24  Brand_Force                   1977 non-null   uint8
#  25  Brand_Ford                    1977 non-null   uint8
#  26  Brand_Honda                   1977 non-null   uint8
#  27  Brand_Hyundai                 1977 non-null   uint8
#  28  Brand_Jaguar                  1977 non-null   uint8
#  29  Brand_Jeep                    1977 non-null   uint8
#  30  Brand_Kia                     1977 non-null   uint8
#  31  Brand_Land                    1977 non-null   uint8
#  32  Brand_Lexus                   1977 non-null   uint8
#  33  Brand_MG                      1977 non-null   uint8
#  34  Brand_Mahindra                1977 non-null   uint8
#  35  Brand_Maruti                  1977 non-null   uint8
#  36  Brand_Mercedes-Benz           1977 non-null   uint8
#  37  Brand_Mitsubishi              1977 non-null   uint8
#  38  Brand_Nissan                  1977 non-null   uint8
#  39  Brand_Renault                 1977 non-null   uint8
#  40  Brand_Skoda                   1977 non-null   uint8
#  41  Brand_Tata                    1977 non-null   uint8
#  42  Brand_Toyota                  1977 non-null   uint8
#  43  Brand_Volkswagen              1977 non-null   uint8
#  44  Brand_Volvo                   1977 non-null   uint8
# dtypes: float64(2), int32(1), int64(2), uint8(40)
# memory usage: 162.2 KB

# %%
# fit the linear regression and predict the values
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
# print the intercept and the coefficients of the model
print("Intercept for linear regression model is: ", round(lr.intercept_,3))
print("Coefficients for linear regression model are: ", np.round(lr.coef_,decimals=3))
# Out:
# Intercept for linear regression model is:  -73755404.792
# Coefficients for linear regression model are:  [ 3.67644230e+04 -7.79000000e-01  6.36536800e+03  6.24354300e+03
#   1.26681000e+02 -1.13566095e+05  4.70945900e+04  7.74532130e+04
#  -1.09817080e+04  7.92554600e+03  1.10800000e+04 -1.90055460e+04
#   6.26463510e+04 -6.26463510e+04  2.48336910e+04  3.39073170e+04
#  -2.79170340e+04 -3.08239740e+04  6.94506132e+05  6.34561276e+05
#  -6.73038606e+05 -1.38475681e+05 -6.94151450e+05 -6.24018464e+05
#  -4.68375239e+05 -5.66794933e+05 -6.06169113e+05 -5.78332102e+05
#   9.38254307e+05  4.30819464e+05 -3.14437353e+05  2.64101722e+06
#   2.81213376e+06  1.05241613e+05 -5.97023846e+05 -5.00767854e+05
#   4.63108346e+05 -6.04181021e+05 -6.41748697e+05 -6.15062962e+05
#  -6.25432500e+05 -7.01452145e+05 -2.68478534e+05 -6.65630720e+05
#   1.16392911e+06]

# %%
# predict the values using liner regression
y_pred = lr.predict(X)

# %%
# calculate the r2 score of the model
print("R2 score for the linear regression model is:", r2_score(y,y_pred))
# Out:
# R2 score for the linear regression model is: 0.8938484185229142

# %%
# import the required sklearn module
from sklearn.model_selection import train_test_split

# split the data in train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.25)
print(X.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (1977, 45)
# (1482, 45)
# (495, 45)

# %%
# fit the linear regression model on training dataset
lr = LinearRegression()
lr.fit(X_train,y_train)
print("Intercept: ",lr.intercept_)
print("Coefficients: ",lr.coef_)
# Out:
# Intercept:  -68523131.329455
# Coefficients:  [ 3.41251490e+04 -1.37122228e+00  6.59481470e+03  6.32908618e+03
#   1.36353861e+02 -1.16555570e+05  5.57927086e+04  8.73981886e+04
#  -2.66353269e+04  3.66075428e+03  2.30060919e+04 -2.66668462e+04
#   5.94199444e+04 -5.94199444e+04  2.58147464e+04  4.84149228e+04
#  -4.45337443e+04 -2.96959250e+04  6.96901765e+05  8.62074256e+05
#  -5.73492969e+05 -7.36422155e+04 -6.20037462e+05 -5.13701500e+05
#  -4.07319810e+05 -4.79840374e+05 -5.18337761e+05 -4.82362014e+05
#   9.70026272e+05  9.05816208e+05 -2.54338400e+05 -1.16415322e-10
#   2.89501304e+06  2.01942176e+05 -5.04065699e+05 -4.08120750e+05
#   5.87623357e+05 -4.86595224e+05 -5.61201072e+05 -5.25056147e+05
#  -4.92372459e+05 -6.06259447e+05 -1.31874389e+05 -5.93985556e+05
#   1.11320618e+06]

# %%
# predict the values from model on test set
y_pred = lr.predict(X_test)

# evaluate the model using R2 score
print("R2 Score: ", r2_score(y_test, y_pred))
# Out:
# R2 Score:  0.8351339964363518

# %%
X = car_data_m.drop(columns='Selling_Price').copy()
car_data_multi_val = pd.get_dummies(X[['Fuel','Transmission','Brand','City_Name']])
car_data_multi_val

# concat the ohe_fuel dummies with original dataframe X
X = pd.concat([X,car_data_multi_val], axis=1)


# drop the column Fuel Type from original dataframe X
X.drop(columns=['Fuel','Seller_Type','Transmission','Owner','City_Name','Name','Brand','Seats','Engine_cc','Power','km_Driven'],inplace=True)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1977 entries, 0 to 1999
# Data columns (total 64 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    1977 non-null   int64
#  1   Mileage_float           1977 non-null   float64
#  2   Fuel_CNG                1977 non-null   uint8
#  3   Fuel_Diesel             1977 non-null   uint8
#  4   Fuel_LPG                1977 non-null   uint8
#  5   Fuel_Petrol             1977 non-null   uint8
#  6   Transmission_Automatic  1977 non-null   uint8
#  7   Transmission_Manual     1977 non-null   uint8
#  8   Brand_Audi              1977 non-null   uint8
#  9   Brand_BMW               1977 non-null   uint8
#  10  Brand_Chevrolet         1977 non-null   uint8
#  11  Brand_Daewoo            1977 non-null   uint8
#  12  Brand_Datsun            1977 non-null   uint8
#  13  Brand_Fiat              1977 non-null   uint8
#  14  Brand_Force             1977 non-null   uint8
#  15  Brand_Ford              1977 non-null   uint8
#  16  Brand_Honda             1977 non-null   uint8
#  17  Brand_Hyundai           1977 non-null   uint8
#  18  Brand_Jaguar            1977 non-null   uint8
#  19  Brand_Jeep              1977 non-null   uint8
#  20  Brand_Kia               1977 non-null   uint8
#  21  Brand_Land              1977 non-null   uint8
#  22  Brand_Lexus             1977 non-null   uint8
#  23  Brand_MG                1977 non-null   uint8
#  24  Brand_Mahindra          1977 non-null   uint8
#  25  Brand_Maruti            1977 non-null   uint8
#  26  Brand_Mercedes-Benz     1977 non-null   uint8
#  27  Brand_Mitsubishi        1977 non-null   uint8
#  28  Brand_Nissan            1977 non-null   uint8
#  29  Brand_Renault           1977 non-null   uint8
#  30  Brand_Skoda             1977 non-null   uint8
#  31  Brand_Tata              1977 non-null   uint8
#  32  Brand_Toyota            1977 non-null   uint8
#  33  Brand_Volkswagen        1977 non-null   uint8
#  34  Brand_Volvo             1977 non-null   uint8
#  35  City_Name_Ahmedabad     1977 non-null   uint8
#  36  City_Name_Aurangabad    1977 non-null   uint8
#  37  City_Name_Bangalore     1977 non-null   uint8
#  38  City_Name_Bhubaneshwar  1977 non-null   uint8
#  39  City_Name_Chennai       1977 non-null   uint8
#  40  City_Name_Coimbatore    1977 non-null   uint8
#  41  City_Name_Dehradun      1977 non-null   uint8
#  42  City_Name_Delhi         1977 non-null   uint8
#  43  City_Name_Gangtok       1977 non-null   uint8
#  44  City_Name_Hyderabad     1977 non-null   uint8
#  45  City_Name_Indore        1977 non-null   uint8
#  46  City_Name_Jaipur        1977 non-null   uint8
#  47  City_Name_Jamshedpur    1977 non-null   uint8
#  48  City_Name_Kochi         1977 non-null   uint8
#  49  City_Name_Kolkata       1977 non-null   uint8
#  50  City_Name_Ludhiana      1977 non-null   uint8
#  51  City_Name_Mangalore     1977 non-null   uint8
#  52  City_Name_Mumbai        1977 non-null   uint8
#  53  City_Name_Mysore        1977 non-null   uint8
#  54  City_Name_Nellore       1977 non-null   uint8
#  55  City_Name_Noida         1977 non-null   uint8
#  56  City_Name_Patna         1977 non-null   uint8
#  57  City_Name_Pune          1977 non-null   uint8
#  58  City_Name_Ranchi        1977 non-null   uint8
#  59  City_Name_Surat         1977 non-null   uint8
#  60  City_Name_Thrissur      1977 non-null   uint8
#  61  City_Name_Vadodara      1977 non-null   uint8
#  62  City_Name_Vellore       1977 non-null   uint8
#  63  City_Name_kanpur        1977 non-null   uint8
# dtypes: float64(1), int64(1), uint8(62)
# memory usage: 166.0 KB

# %%
# fit the linear regression and predict the values
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
# print the intercept and the coefficients of the model
print("Intercept for linear regression model is: ", round(lr.intercept_,3))
print("Coefficients for linear regression model are: ", np.round(lr.coef_,decimals=3))
# Out:
# Intercept for linear regression model is:  5080560889421860.0
# Coefficients for linear regression model are:  [ 5.83775430e+04 -2.17172150e+04  4.11392701e+15  4.11392701e+15
#   4.11392701e+15  4.11392701e+15 -9.16961490e+15 -9.16961490e+15
#   3.07582618e+14  3.07582619e+14  3.07582617e+14  3.07582617e+14
#   3.07582617e+14  3.07582617e+14  3.07582617e+14  3.07582617e+14
#   3.07582617e+14  3.07582617e+14  3.07582619e+14  3.07582618e+14
#   3.07582617e+14  3.07582620e+14  3.07582621e+14  3.07582618e+14
#   3.07582617e+14  3.07582617e+14  3.07582618e+14  3.07582617e+14
#   3.07582617e+14  3.07582617e+14  3.07582617e+14  3.07582617e+14
#   3.07582617e+14  3.07582617e+14  3.07582619e+14 -3.32455734e+14
#  -3.32455734e+14 -3.32455734e+14 -3.32455734e+14 -3.32455734e+14
#  -3.32455734e+14 -3.32455734e+14 -3.32455734e+14 -3.32455734e+14
#  -3.32455734e+14 -3.32455734e+14 -3.32455734e+14 -3.32455734e+14
#  -3.32455734e+14 -3.32455734e+14 -3.32455734e+14 -3.32455734e+14
#  -3.32455734e+14 -3.32455734e+14 -3.32455734e+14 -3.32455734e+14
#  -3.32455734e+14 -3.32455734e+14 -3.32455734e+14 -3.32455734e+14
#  -3.32455734e+14 -3.32455734e+14 -3.32455734e+14 -3.32455734e+14]

# %%
# predict the values using liner regression
y_pred = lr.predict(X)

# %%
# calculate the r2 score of the model
print("R2 score for the linear regression model is:", r2_score(y,y_pred))
# Out:
# R2 score for the linear regression model is: 0.8533466227343778

# %%
# import the required sklearn module
from sklearn.model_selection import train_test_split

# split the data in train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.25)
print(X.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (1977, 64)
# (1482, 64)
# (495, 64)

# %%
# fit the linear regression model on training dataset
lr = LinearRegression()
lr.fit(X_train,y_train)
print("Intercept: ",lr.intercept_)
print("Coefficients: ",lr.coef_)
# Out:
# Intercept:  -2.2241402336592324e+16
# Coefficients:  [ 5.76854556e+04 -1.79295475e+04 -2.90170930e+16 -2.90170930e+16
#  -2.90170930e+16 -2.90170930e+16  9.32464792e+16  9.32464792e+16
#  -2.36807950e+16 -2.36807950e+16 -2.36807950e+16 -2.36807950e+16
#  -2.36807950e+16 -2.36807950e+16 -2.36807950e+16 -2.36807950e+16
#  -2.36807950e+16 -2.36807950e+16 -2.36807950e+16 -2.36807949e+16
#  -2.36807950e+16 -2.36807949e+16 -2.36807949e+16 -2.36807950e+16
#  -2.36807950e+16 -2.36807950e+16 -2.36807950e+16 -2.36807950e+16
#  -2.36807950e+16 -2.36807950e+16 -2.36807950e+16 -2.36807950e+16
#  -2.36807950e+16 -2.36807950e+16 -2.36807949e+16 -1.83071891e+16
#  -1.83071891e+16 -1.83071891e+16 -1.83071891e+16 -1.83071891e+16
#  -1.83071891e+16 -1.83071891e+16 -1.83071891e+16 -1.83071891e+16
#  -1.83071891e+16 -1.83071891e+16 -1.83071891e+16 -1.83071891e+16
#  -1.83071891e+16 -1.83071891e+16 -1.83071891e+16 -1.83071891e+16
#  -1.83071891e+16 -1.83071891e+16 -1.83071891e+16 -1.83071891e+16
#  -1.83071891e+16 -1.83071891e+16 -1.83071891e+16 -1.83071891e+16
#  -1.83071891e+16 -1.83071891e+16 -1.83071891e+16 -1.83071891e+16]

# %%
# predict the values from model on test set
y_pred = lr.predict(X_test)

# evaluate the model using R2 score
print("R2 Score: ", r2_score(y_test, y_pred))
# Out:
# R2 Score:  0.8422551219658971

# %%
plt.figure(figsize=(10,8))
sns.heatmap(X.corr(), annot=True, cmap="summer", vmin=0, vmax=1)
plt.show()

# %%
X = car_data_m.drop(columns='Selling_Price').copy()
car_data_multi_val = pd.get_dummies(X[['Fuel','Brand','City_Name','Seller_Type','Transmission','Owner']])
car_data_multi_val

# concat the ohe_fuel dummies with original dataframe X
X = pd.concat([X,car_data_multi_val], axis=1)


# drop the column Fuel Type from original dataframe X
X.drop(columns=['Fuel','Seller_Type','Transmission','Owner','City_Name','Name','Brand'],inplace=True)
X.info()
# fit the linear regression and predict the values
lr = LinearRegression()
lr.fit(X,y)
# print the intercept and the coefficients of the model
print("Intercept for linear regression model is: ", round(lr.intercept_,3))
print("Coefficients for linear regression model are: ", np.round(lr.coef_,decimals=3))
# predict the values using liner regression
y_pred = lr.predict(X)
# calculate the r2 score of the model
print("R2 score for the linear regression model is:", r2_score(y,y_pred))
# import the required sklearn module
from sklearn.model_selection import train_test_split

# split the data in train and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.25)
print(X.shape)
print(X_train.shape)
print(X_test.shape)
# fit the linear regression model on training dataset
lr = LinearRegression()
lr.fit(X_train,y_train)
print("Intercept: ",lr.intercept_)
print("Coefficients: ",lr.coef_)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1977 entries, 0 to 1999
# Data columns (total 75 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          1977 non-null   int64
#  1   km_Driven                     1977 non-null   int64
#  2   Seats                         1977 non-null   int64
#  3   Mileage_float                 1977 non-null   float64
#  4   Power                         1977 non-null   float64
#  5   Engine_cc                     1977 non-null   int32
#  6   Fuel_CNG                      1977 non-null   uint8
#  7   Fuel_Diesel                   1977 non-null   uint8
#  8   Fuel_LPG                      1977 non-null   uint8
#  9   Fuel_Petrol                   1977 non-null   uint8
#  10  Brand_Audi                    1977 non-null   uint8
#  11  Brand_BMW                     1977 non-null   uint8
#  12  Brand_Chevrolet               1977 non-null   uint8
#  13  Brand_Daewoo                  1977 non-null   uint8
#  14  Brand_Datsun                  1977 non-null   uint8
#  15  Brand_Fiat                    1977 non-null   uint8
#  16  Brand_Force                   1977 non-null   uint8
#  17  Brand_Ford                    1977 non-null   uint8
#  18  Brand_Honda                   1977 non-null   uint8
#  19  Brand_Hyundai                 1977 non-null   uint8
#  20  Brand_Jaguar                  1977 non-null   uint8
#  21  Brand_Jeep                    1977 non-null   uint8
#  22  Brand_Kia                     1977 non-null   uint8
#  23  Brand_Land                    1977 non-null   uint8
#  24  Brand_Lexus                   1977 non-null   uint8
#  25  Brand_MG                      1977 non-null   uint8
#  26  Brand_Mahindra                1977 non-null   uint8
#  27  Brand_Maruti                  1977 non-null   uint8
#  28  Brand_Mercedes-Benz           1977 non-null   uint8
#  29  Brand_Mitsubishi              1977 non-null   uint8
#  30  Brand_Nissan                  1977 non-null   uint8
#  31  Brand_Renault                 1977 non-null   uint8
#  32  Brand_Skoda                   1977 non-null   uint8
#  33  Brand_Tata                    1977 non-null   uint8
#  34  Brand_Toyota                  1977 non-null   uint8
#  35  Brand_Volkswagen              1977 non-null   uint8
#  36  Brand_Volvo                   1977 non-null   uint8
#  37  City_Name_Ahmedabad           1977 non-null   uint8
#  38  City_Name_Aurangabad          1977 non-null   uint8
#  39  City_Name_Bangalore           1977 non-null   uint8
#  40  City_Name_Bhubaneshwar        1977 non-null   uint8
#  41  City_Name_Chennai             1977 non-null   uint8
#  42  City_Name_Coimbatore          1977 non-null   uint8
#  43  City_Name_Dehradun            1977 non-null   uint8
#  44  City_Name_Delhi               1977 non-null   uint8
#  45  City_Name_Gangtok             1977 non-null   uint8
#  46  City_Name_Hyderabad           1977 non-null   uint8
#  47  City_Name_Indore              1977 non-null   uint8
#  48  City_Name_Jaipur              1977 non-null   uint8
#  49  City_Name_Jamshedpur          1977 non-null   uint8
#  50  City_Name_Kochi               1977 non-null   uint8
#  51  City_Name_Kolkata             1977 non-null   uint8
#  52  City_Name_Ludhiana            1977 non-null   uint8
#  53  City_Name_Mangalore           1977 non-null   uint8
#  54  City_Name_Mumbai              1977 non-null   uint8
#  55  City_Name_Mysore              1977 non-null   uint8
#  56  City_Name_Nellore             1977 non-null   uint8
#  57  City_Name_Noida               1977 non-null   uint8
#  58  City_Name_Patna               1977 non-null   uint8
#  59  City_Name_Pune                1977 non-null   uint8
#  60  City_Name_Ranchi              1977 non-null   uint8
#  61  City_Name_Surat               1977 non-null   uint8
#  62  City_Name_Thrissur            1977 non-null   uint8
#  63  City_Name_Vadodara            1977 non-null   uint8
#  64  City_Name_Vellore             1977 non-null   uint8
#  65  City_Name_kanpur              1977 non-null   uint8
#  66  Seller_Type_Dealer            1977 non-null   uint8
#  67  Seller_Type_Individual        1977 non-null   uint8
#  68  Seller_Type_Trustmark Dealer  1977 non-null   uint8
#  69  Transmission_Automatic        1977 non-null   uint8
#  70  Transmission_Manual           1977 non-null   uint8
#  71  Owner_First Owner             1977 non-null   uint8
#  72  Owner_Fourth & Above Owner    1977 non-null   uint8
#  73  Owner_Second Owner            1977 non-null   uint8
#  74  Owner_Third Owner             1977 non-null   uint8
# dtypes: float64(2), int32(1), int64(3), uint8(69)
# memory usage: 233.6 KB
# Intercept for linear regression model is:  -75549674.255
# Coefficients for linear regression model are:  [ 3.76798980e+04 -7.93000000e-01 -9.06355600e+03  5.76332300e+03
#   6.17012600e+03  1.36740000e+02 -1.26181933e+05  4.93559770e+04
#   8.72741370e+04 -1.04481810e+04  7.07739142e+05  6.34643416e+05
#  -6.73633059e+05 -1.45091102e+05 -7.02054677e+05 -6.24882824e+05
#  -4.60577072e+05 -5.64320984e+05 -6.05266989e+05 -5.78861171e+05
#   9.30895770e+05  4.20382722e+05 -3.06403884e+05  2.63652636e+06
#   2.79866716e+06  1.09721654e+05 -5.84920083e+05 -4.99482237e+05
#   4.57715144e+05 -5.98884662e+05 -6.44108579e+05 -6.08892118e+05
#  -6.29491883e+05 -7.02369280e+05 -2.67352260e+05 -6.64310289e+05
#   1.16461179e+06 -3.97597870e+04 -1.75132050e+04 -2.92813600e+03
#  -2.73132780e+04  1.52634370e+04 -8.54134000e+02  2.81703680e+04
#  -1.89369000e+02 -1.39227360e+04  2.07301900e+04 -6.63801550e+04
#   1.03349050e+04  1.37329800e+03  4.34773880e+04 -1.45599680e+04
#   3.87805730e+04 -2.18229000e+03  1.08090410e+04 -2.15407360e+04
#   5.09043200e+04  3.64555820e+04  2.65094880e+04 -8.91463600e+03
#  -6.75231900e+03 -2.26750750e+04  1.29456230e+04  6.76123000e+02
#  -2.28811860e+04 -2.80633270e+04  8.82362300e+03  1.33303410e+04
#  -2.21539640e+04  6.11249340e+04 -6.11249340e+04  2.29070890e+04
#   3.54241730e+04 -2.93932830e+04 -2.89379780e+04]
# R2 score for the linear regression model is: 0.8952930533383432
# (1977, 75)
# (1482, 75)
# (495, 75)
# Intercept:  -79639377.66203278
# Coefficients:  [ 3.96970161e+04 -7.00558106e-01 -9.04994191e+03  6.47066228e+03
#   6.17595375e+03  1.57292078e+02 -1.37594644e+05  4.65151729e+04
#   9.24519468e+04 -1.37247552e+03  6.75503915e+05  8.84061313e+05
#  -7.15255478e+05 -1.51777440e+05 -7.41770074e+05 -6.48602475e+05
#  -5.20490861e+05 -6.11786456e+05 -6.34212374e+05 -6.25335843e+05
#   9.05225173e+05  5.35841211e+05  2.27569203e+05  2.58006076e+06
#   2.75010089e+06  1.34072241e+05 -6.32017348e+05 -5.38690032e+05
#   3.51867267e+05 -6.62733016e+05 -6.68233980e+05 -6.56619353e+05
#  -6.26631149e+05 -7.56386022e+05 -2.95223466e+05 -7.11223335e+05
#   1.15268673e+06 -5.33565605e+04 -4.05989174e+03 -2.06247769e+04
#   1.07784681e+04  1.31012578e+04 -9.35154638e+03  3.60277120e+04
#  -8.16623337e+03  3.58990923e+02  1.85372587e+04 -7.38791088e+04
#   1.72256681e+03 -2.40075777e+04  5.15276427e+04 -2.74637710e+03
#   2.48305144e+04  4.91809832e+03 -1.69553283e+03 -8.48727274e+02
#   6.76727355e+04  4.12375414e+04  4.36833796e+04 -4.61513245e+04
#  -4.11177047e+04 -5.98039766e+03  4.53148926e+04 -2.96822653e+03
#  -3.21513884e+04 -3.26056843e+04  1.67575299e+04  2.24686899e+04
#  -3.92262198e+04  4.72893106e+04 -4.72893106e+04  1.98246573e+04
#   5.48691888e+04 -3.35290665e+04 -4.11647796e+04]

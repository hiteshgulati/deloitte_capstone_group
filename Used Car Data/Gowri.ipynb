# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import os

# %%
os.getcwd()
# Out:
# 'C:\\AI_Program_Capstone\\Capstone3_UsedCarsData'

# %%
os.chdir('C:\\AI_Program_Capstone\\Capstone3_UsedCarsData')

# %%
os.getcwd()
# Out:
# 'C:\\AI_Program_Capstone\\Capstone3_UsedCarsData'

# %%
df_car_sales_trans = pd.read_csv('Car_sales_transactions.csv',header=0,sep=',',encoding='latin')

# %% [markdown]
# #### Read the Car_sales_transactions.csv file and store the result to df_car_sales_trans dataframe

# %%
df_car_sales_status = pd.read_csv('Sales_Status.csv',header=0,sep=',',encoding='latin')

# %% [markdown]
# #### Read the Car_sales_status.csv file and store the result to df_car_sales_status dataframe

# %%
df_car_sales_trans.columns
# Out:
# Index(['Sales_ID', 'Name', 'Year', 'Selling_Price', 'km_Driven', 'City_Code',
#        'State_Code', 'Postal_Code', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Mileage', 'Engine', 'Max_Power', 'Seats'],
#       dtype='object')

# %%
df_car_sales_status.columns
# Out:
# Index(['Sales_ID', 'Sold'], dtype='object')

# %%
df_car_sales_rep = pd.merge(df_car_sales_trans,df_car_sales_status,how='left',left_on='Sales_ID',right_on='Sales_ID')

# %% [markdown]
# #### Merged df_car_sales_trans and df_car_sales_status dataframes using left join on Sales_ID column ####

# %%
df_car_sales_rep.columns
# Out:
# Index(['Sales_ID', 'Name', 'Year', 'Selling_Price', 'km_Driven', 'City_Code',
#        'State_Code', 'Postal_Code', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Mileage', 'Engine', 'Max_Power', 'Seats', 'Sold'],
#       dtype='object')

# %%
df_car_sales_rep['Sold_Mapped'] = (df_car_sales_rep['Sold']=='Y').map({True:1, False:0})

# %% [markdown]
# #### Mapped all the values('Y'/'N') of Sold Column to 1 and 0 and stored in Sold_Mapped column of df_car_sales_rep dataframe####

# %%
df_car_sales_rep.columns
# Out:
# Index(['Sales_ID', 'Name', 'Year', 'Selling_Price', 'km_Driven', 'City_Code',
#        'State_Code', 'Postal_Code', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Mileage', 'Engine', 'Max_Power', 'Seats', 'Sold',
#        'Sold_Mapped'],
#       dtype='object')

# %%
df_car_sales_rep.shape
# Out:
# (7906, 18)

# %% [markdown]
# #### Verified number of rows matching with Car_sales_transactions.csv file ####

# %%
df_city = pd.read_excel('City_Master.xlsx',header=0)

# %% [markdown]
# #### Read the City_Master.xlsx file and store the result to df_city dataframe ####

# %%
df_state = pd.read_excel('State_Master.xlsx',header=0)

# %% [markdown]
# #### Read the State_Master.xlsx file and store the result to df_state dataframe ####

# %%
df_rep_with_state= pd.merge(df_car_sales_rep,df_state,how='left',left_on='State_Code',right_on='State_Code')

# %% [markdown]
# #### Merge df_car_sales_rep and  df_state using left join on State_Code and stored the result to df_rep_with_state dataframe

# %%
df_used_cars_rep = pd.merge(df_rep_with_state,df_city,how='left',left_on='City_Code',right_on='City_Code')

# %% [markdown]
# #### Merge df_car_sales_rep and  df_state using left join on State_Code and stored the result to df_rep_with_state dataframe

# %%
df_used_cars_rep.columns
# Out:
# Index(['Sales_ID', 'Name', 'Year', 'Selling_Price', 'km_Driven', 'City_Code',
#        'State_Code_x', 'Postal_Code', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Mileage', 'Engine', 'Max_Power', 'Seats', 'Sold',
#        'Sold_Mapped', 'State_Name', 'City_Name', 'State_Code_y'],
#       dtype='object')

# %%
df_used_cars_rep.head(5)
# Out:
#    Sales_ID                          Name  Year  Selling_Price  km_Driven  \
# 0         1        Maruti Swift Dzire VDI  2014         450000     145500
# 1         2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         3      Honda City 2017-2020 EXi  2006         158000     140000
# 3         4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4         5        Maruti Swift VXI BSIII  2007         130000     120000
#
#   City_Code State_Code_x  Postal_Code    Fuel Seller_Type  ...         Owner  \
# 0      CT01         ST15       400001  Diesel  Individual  ...   First Owner
# 1      CT28         ST11       834001  Diesel  Individual  ...  Second Owner
# 2      CT12         ST28       201301  Petrol  Individual  ...   Third Owner
# 3      CT21         ST27       248001  Diesel  Individual  ...   First Owner
# 4      CT03         ST24       600020  Petrol  Individual  ...   First Owner
#
# ...

# %% [markdown]
# #### Displayed first 5 rows of df_used_cars_rep dataframe ####

# %%
df_used_cars_rep.columns
# Out:
# Index(['Sales_ID', 'Name', 'Year', 'Selling_Price', 'km_Driven', 'City_Code',
#        'State_Code_x', 'Postal_Code', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Mileage', 'Engine', 'Max_Power', 'Seats', 'Sold',
#        'Sold_Mapped', 'State_Name', 'City_Name', 'State_Code_y'],
#       dtype='object')

# %%
df_used_cars_rep.drop('State_Code_y',axis=True,inplace=True)

# %% [markdown]
# #### dropped the redundant column State_Code_y from the df_used_cars_rep dataframe ####

# %%
df_used_cars_rep.columns
# Out:
# Index(['Sales_ID', 'Name', 'Year', 'Selling_Price', 'km_Driven', 'City_Code',
#        'State_Code_x', 'Postal_Code', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Mileage', 'Engine', 'Max_Power', 'Seats', 'Sold',
#        'Sold_Mapped', 'State_Name', 'City_Name'],
#       dtype='object')

# %%
df_region_state = pd.read_excel('Region_State_Mapping.xlsx',header=0)

# %% [markdown]
# #### read the file Region_State_Mapping.xlsx file and stored to df_region_state dataframe ####

# %%
df_region_state.columns
# Out:
# Index(['Region_Code', 'State_Code'], dtype='object')

# %%
df_used_cars_rep = pd.merge(df_used_cars_rep,df_region_state,how='left',left_on='State_Code_x',right_on='State_Code')

# %% [markdown]
# #### merged df_used_cars_rep dataframe and df_region_state using left join on  State_Code column ####

# %%
df_used_cars_rep.head(5)
# Out:
#    Sales_ID                          Name  Year  Selling_Price  km_Driven  \
# 0         1        Maruti Swift Dzire VDI  2014         450000     145500
# 1         2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         3      Honda City 2017-2020 EXi  2006         158000     140000
# 3         4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4         5        Maruti Swift VXI BSIII  2007         130000     120000
#
#   City_Code State_Code_x  Postal_Code    Fuel Seller_Type  ...     Mileage  \
# 0      CT01         ST15       400001  Diesel  Individual  ...   23.4 kmpl
# 1      CT28         ST11       834001  Diesel  Individual  ...  21.14 kmpl
# 2      CT12         ST28       201301  Petrol  Individual  ...   17.7 kmpl
# 3      CT21         ST27       248001  Diesel  Individual  ...   23.0 kmpl
# 4      CT03         ST24       600020  Petrol  Individual  ...   16.1 kmpl
#
# ...

# %%
df_used_cars_rep.columns
# Out:
# Index(['Sales_ID', 'Name', 'Year', 'Selling_Price', 'km_Driven', 'City_Code',
#        'State_Code_x', 'Postal_Code', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Mileage', 'Engine', 'Max_Power', 'Seats', 'Sold',
#        'Sold_Mapped', 'State_Name', 'City_Name', 'Region_Code', 'State_Code'],
#       dtype='object')

# %%
df_used_cars_rep.columns[-1]
# Out:
# 'State_Code'

# %%
df_used_cars_rep.drop(df_used_cars_rep.columns[-1], axis = 1, inplace = True)

# %% [markdown]
# #### dropped the redundant column State_code from df_used_cars_rep repository ####

# %%
df_used_cars_rep.head(5)
# Out:
#    Sales_ID                          Name  Year  Selling_Price  km_Driven  \
# 0         1        Maruti Swift Dzire VDI  2014         450000     145500
# 1         2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         3      Honda City 2017-2020 EXi  2006         158000     140000
# 3         4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4         5        Maruti Swift VXI BSIII  2007         130000     120000
#
#   City_Code State_Code_x  Postal_Code    Fuel Seller_Type  ...         Owner  \
# 0      CT01         ST15       400001  Diesel  Individual  ...   First Owner
# 1      CT28         ST11       834001  Diesel  Individual  ...  Second Owner
# 2      CT12         ST28       201301  Petrol  Individual  ...   Third Owner
# 3      CT21         ST27       248001  Diesel  Individual  ...   First Owner
# 4      CT03         ST24       600020  Petrol  Individual  ...   First Owner
#
# ...

# %% [markdown]
# #### diplayed first 5 rows after removing redundant columns ####

# %%
df_used_cars_rep.columns
# Out:
# Index(['Sales_ID', 'Name', 'Year', 'Selling_Price', 'km_Driven', 'City_Code',
#        'State_Code_x', 'Postal_Code', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Mileage', 'Engine', 'Max_Power', 'Seats', 'Sold',
#        'Sold_Mapped', 'State_Name', 'City_Name', 'Region_Code'],
#       dtype='object')

# %%
df_region_master = pd.read_excel('Region_Master.xlsx',header=0)

# %% [markdown]
# #### read the Region_Master.xlsx file and store it in df_region_master dataframe ####

# %%
df_used_cars_rep = pd.merge(df_used_cars_rep,df_region_master,how='left',left_on='Region_Code',right_on='Region_Code')

# %% [markdown]
# #### Merge df_used_cars_rep and df_region_master dataframes using left join and store it again in df_used_cars_rep dataframe

# %%
df_used_cars_rep.shape
# Out:
# (7906, 22)

# %%
df_used_cars_rep.columns
# Out:
# Index(['Sales_ID', 'Name', 'Year', 'Selling_Price', 'km_Driven', 'City_Code',
#        'State_Code_x', 'Postal_Code', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Mileage', 'Engine', 'Max_Power', 'Seats', 'Sold',
#        'Sold_Mapped', 'State_Name', 'City_Name', 'Region_Code', 'Region'],
#       dtype='object')

# %%
df_used_cars_rep.head(5)
# Out:
#    Sales_ID                          Name  Year  Selling_Price  km_Driven  \
# 0         1        Maruti Swift Dzire VDI  2014         450000     145500
# 1         2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         3      Honda City 2017-2020 EXi  2006         158000     140000
# 3         4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4         5        Maruti Swift VXI BSIII  2007         130000     120000
#
#   City_Code State_Code_x  Postal_Code    Fuel Seller_Type  ...     Mileage  \
# 0      CT01         ST15       400001  Diesel  Individual  ...   23.4 kmpl
# 1      CT28         ST11       834001  Diesel  Individual  ...  21.14 kmpl
# 2      CT12         ST28       201301  Petrol  Individual  ...   17.7 kmpl
# 3      CT21         ST27       248001  Diesel  Individual  ...   23.0 kmpl
# 4      CT03         ST24       600020  Petrol  Individual  ...   16.1 kmpl
#
# ...

# %%
df_used_cars_rep['Name'].head(5)
# Out:
# 0          Maruti Swift Dzire VDI
# 1    Skoda Rapid 1.5 TDI Ambition
# 2        Honda City 2017-2020 EXi
# 3       Hyundai i20 Sportz Diesel
# 4          Maruti Swift VXI BSIII
# Name: Name, dtype: object

# %%
df_used_cars_rep['Brand'] = df_used_cars_rep['Name'].str.split(' ', 1).str[0]

# %% [markdown]
# #### added Brand column to df_used_cars_rep dataframe####

# %%
df_used_cars_rep.head(5)
# Out:
#    Sales_ID                          Name  Year  Selling_Price  km_Driven  \
# 0         1        Maruti Swift Dzire VDI  2014         450000     145500
# 1         2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         3      Honda City 2017-2020 EXi  2006         158000     140000
# 3         4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4         5        Maruti Swift VXI BSIII  2007         130000     120000
#
#   City_Code State_Code_x  Postal_Code    Fuel Seller_Type  ...   Engine  \
# 0      CT01         ST15       400001  Diesel  Individual  ...  1248 CC
# 1      CT28         ST11       834001  Diesel  Individual  ...  1498 CC
# 2      CT12         ST28       201301  Petrol  Individual  ...  1497 CC
# 3      CT21         ST27       248001  Diesel  Individual  ...  1396 CC
# 4      CT03         ST24       600020  Petrol  Individual  ...  1298 CC
#
#     Max_Power Seats Sold Sold_Mapped     State_Name City_Name  Region_Code  \
# ...

# %%
#No of cars sold brandwise on each region by brand
df_used_cars_rep.query("Sold == 'Y'").groupby(['Brand'],as_index=False).size().rename(columns={'size':'Total_Sold'}).sort_values('Total_Sold',ascending=False).head(5)
# Out:
#        Brand  Total_Sold
# 17    Maruti         597
# 9    Hyundai         332
# 16  Mahindra         201
# 23      Tata         178
# 24    Toyota         126

# %% [markdown]
# #### Top 5 Brand solds across the regions ####

# %%
#No of cars sold brandwise on each region by brand
df_used_cars_rep.query("Sold == 'Y'").groupby(['Brand','City_Name'],as_index=False).size().rename(columns={'size':'Total_Sold'}).sort_values('Total_Sold',ascending=False).head(15)
# Out:
#       Brand  City_Name  Total_Sold
# 235  Maruti  Mangalore          32
# 225  Maruti   Dehradun          30
# 243  Maruti      Surat          27
# 228  Maruti  Hyderabad          25
# 232  Maruti      Kochi          25
# 236  Maruti     Mumbai          24
# 246  Maruti    Vellore          24
# 227  Maruti    Gangtok          23
# 237  Maruti     Mysore          23
# 239  Maruti      Noida          23
# 226  Maruti      Delhi          22
# 223  Maruti    Chennai          21
# 245  Maruti   Vadodara          21
# 242  Maruti     Ranchi          20
# 240  Maruti      Patna          20

# %% [markdown]
# #### first 15 rows who sold across city names ####

# %%
#No of cars sold brandwise on East region (Maruti dominated refer below query for specific brands)
df_used_cars_rep.query("Sold == 'Y' & Region=='East'").groupby(['Brand','Region','State_Name','City_Name'],as_index=False).size().rename(columns={'size':'Total_Sold'}).sort_values('Total_Sold',ascending=False).head(5)
#df_used_cars_rep.query("Sold == 'Y' & Region=='East'").groupby(['Brand','Name','Region','State_Name','City_Name'],as_index=False).size().sort_values('size',ascending=False).head(15)
# Out:
#      Brand Region   State_Name     City_Name  Total_Sold
# 38  Maruti   East        Bihar         Patna          20
# 42  Maruti   East  West Bengal       Kolkata          20
# 40  Maruti   East    Jharkhand        Ranchi          20
# 41  Maruti   East       Odisha  Bhubaneshwar          15
# 39  Maruti   East    Jharkhand    Jamshedpur          12

# %% [markdown]
# ####  maximum number of cars sold by different brand with East Region and State names ####

# %%
#No of cars sold brandwise on West region (Maruti dominated refer below query for specific brands)
df_used_cars_rep.query("Sold == 'Y' & Region=='West'").groupby(['Brand','Region','State_Name','City_Name'],as_index=False).size().rename(columns={'size':'Total_Sold'}).sort_values('Total_Sold',ascending=False).head(5)
#df_used_cars_rep.query("Sold == 'Y' & Region=='West'").groupby(['Brand','Name','Region','State_Name','City_Name'],as_index=False).size().rename(columns={'size':'Total_Sold'}).sort_values('Total_Sold',ascending=False).head(15)
# Out:
#      Brand Region   State_Name   City_Name  Total_Sold
# 39  Maruti   West      Gujarat       Surat          27
# 42  Maruti   West  Maharashtra      Mumbai          24
# 40  Maruti   West      Gujarat    Vadodara          21
# 38  Maruti   West      Gujarat   Ahmedabad          18
# 41  Maruti   West  Maharashtra  Aurangabad          17

# %% [markdown]
# ####  maximum number of cars sold by different brand with West Region and State names ####

# %%
#No of cars sold brandwise on North region (Maruti dominated refer below query for specific brands)
df_used_cars_rep.query("Sold == 'Y' & Region=='North'").groupby(['Brand','Region','State_Name','City_Name'],as_index=False).size().rename(columns={'size':'Total_Sold'}).sort_values('Total_Sold',ascending=False).head(5)
#df_used_cars_rep.query("Sold == 'Y' & Region=='North'").groupby(['Brand','Name','Region','State_Name','City_Name'],as_index=False).size().rename(columns={'size':'Total_Sold'}).sort_values('Total_Sold',ascending=False).head(5)
# Out:
#       Brand Region State_Name City_Name  Total_Sold
# 24   Maruti  North      Delhi     Delhi          22
# 25   Maruti  North     Punjab  Ludhiana          17
# 15  Hyundai  North      Delhi     Delhi          15
# 26   Maruti  North  Rajasthan    Jaipur          13
# 35   Toyota  North      Delhi     Delhi          11

# %% [markdown]
# ####  maximum number of cars sold by different brand with North Region and State names ####

# %%
#No of cars sold brandwise on South region (Maruti dominated refer below query for specific brands)
df_used_cars_rep.query("Sold == 'Y' & Region=='South'").groupby(['Brand','Region','State_Name','City_Name'],as_index=False).size().rename(columns={'size':'Total_Sold'}).sort_values('Total_Sold',ascending=False).head(5)
#df_used_cars_rep.query("Sold == 'Y' & Region=='North'").groupby(['Brand','Name','Region','State_Name','City_Name'],as_index=False).size().rename(columns={'size':'Total_Sold'}).sort_values('Total_Sold',ascending=False).head(5)
# Out:
#      Brand Region  State_Name  City_Name  Total_Sold
# 81  Maruti  South   Karnataka  Mangalore          32
# 88  Maruti  South   Telangana  Hyderabad          25
# 83  Maruti  South      Kerala      Kochi          25
# 87  Maruti  South  Tamil Nadu    Vellore          24
# 82  Maruti  South   Karnataka     Mysore          23

# %% [markdown]
# ####  maximum number of cars sold by different brand with South Region and State names ####

# %%
#TO GET RANGE OF KM DRIVEN AS PER USER'S INTEREST:
#df_car_sales_rep['Sold_Mapped'] = (df_car_sales_rep['Sold']=='Y').map({True:1, False:0})
#km_Driven_range = [5000, 10000, 20000, 40000, 80000,160000,200000,250000,300000]
km_Driven_range = [0,5000, 10000, 20000, 40000, 80000,160000,200000,250000,np.inf]
#names = ['<5K', '10K-20K', '20K-40K', '40K-80K', '80K-160K','160K-200K','200K-250K','250K+']
names = ['0-5K', '5K-10K', '10K-20K', '20K-40K', '40K-80K','80K-160K','160K-200K','200K-250K','250K+']
df_used_cars_rep['km_Driven_range'] = pd.cut(df_used_cars_rep['km_Driven'], km_Driven_range, labels=names)
#d = dict(enumerate(names, 1))

#df['AgeRange'] = np.vectorize(d.get)(np.digitize(df['Age'], bins))

#df_used_cars_rep['km_Driven_range'] = np.vectorize(d.get)(np.digitize(df_used_cars_rep['km_Driven'], km_Driven_range))

# %% [markdown]
# #### divided km_driven column by range and stored it in km_Driven_range column of df_used_cars_rep dataframe ####

# %%
df_used_cars_rep.columns
# Out:
# Index(['Sales_ID', 'Name', 'Year', 'Selling_Price', 'km_Driven', 'City_Code',
#        'State_Code_x', 'Postal_Code', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Mileage', 'Engine', 'Max_Power', 'Seats', 'Sold',
#        'Sold_Mapped', 'State_Name', 'City_Name', 'Region_Code', 'Region',
#        'Brand', 'km_Driven_range'],
#       dtype='object')

# %%
df_used_cars_rep.shape
# Out:
# (7906, 24)

# %%
df_used_cars_rep[df_used_cars_rep['km_Driven']==20000].head(5)
# Out:
#      Sales_ID                         Name  Year  Selling_Price  km_Driven  \
# 127       133                Lexus ES 300h  2019        5150000      20000
# 163       170  Maruti Ertiga BSIV ZXI Plus  2016         850000      20000
# 200       209   Maruti Swift Dzire VXI 1.2  2017         550000      20000
# 201       210          Maruti Alto 800 LXI  2018         270000      20000
# 203       212    Maruti Swift VXI Optional  2017         500000      20000
#
#     City_Code State_Code_x  Postal_Code    Fuel Seller_Type  ...   Max_Power  \
# 127      CT05         ST25       500004  Petrol      Dealer  ...  214.56 bhp
# 163      CT15         ST20       751022  Petrol  Individual  ...    91.1 bhp
# 200      CT25         ST01       524225  Petrol  Individual  ...   81.80 bhp
# 201      CT18         ST21       141003  Petrol  Individual  ...    47.3 bhp
# 203      CT18         ST21       141003  Petrol  Individual  ...   81.80 bhp
#
# ...

# %% [markdown]
# #### verified km_driven_range logic with 20000 kms test case ####

# %%
#df_used_cars_rep.drop(['km_Driven_range'],axis=1,inplace=True)

# %%
# TO GET MODEL BASED ON USER'S INTEREST:
car_model_range = [0,1999,2005, 2011, 2015,2018,np.inf]
names = ['Antique(upto 1999)', 'Very Old(2000-2005)', 'Old(2006-2011)','Moderate(2012-2015)','Fair(2016-2018)','New(2019+)']
df_used_cars_rep['car_model_range'] = pd.cut(df_used_cars_rep['Year'], car_model_range, labels=names)

# %% [markdown]
# #### divided year column by range and stored it in car_model_range of df_used_cars_rep dataframe ####

# %%
df_used_cars_rep.columns
# Out:
# Index(['Sales_ID', 'Name', 'Year', 'Selling_Price', 'km_Driven', 'City_Code',
#        'State_Code_x', 'Postal_Code', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Mileage', 'Engine', 'Max_Power', 'Seats', 'Sold',
#        'Sold_Mapped', 'State_Name', 'City_Name', 'Region_Code', 'Region',
#        'Brand', 'km_Driven_range', 'car_model_range'],
#       dtype='object')

# %%
df_used_cars_rep[df_used_cars_rep['Year']==2005].head(5)
# Out:
#      Sales_ID                Name  Year  Selling_Price  km_Driven City_Code  \
# 11         12       Maruti Zen LX  2005          92000     100000      CT25
# 178       185  Honda City 1.5 EXI  2005         100000     120000      CT13
# 185       192      Maruti Zen LXI  2005          85000      90000      CT14
# 189       196    Hyundai Getz GLS  2005          65000      86000      CT14
# 274       285      Maruti Alto LX  2005         110000      45000      CT01
#
#     State_Code_x  Postal_Code    Fuel Seller_Type  ... Seats Sold Sold_Mapped  \
# 11          ST01       524225  Petrol  Individual  ...     5    Y           1
# 178         ST04       800002  Petrol  Individual  ...     5    Y           1
# 185         ST07       395007  Petrol  Individual  ...     5    Y           1
# 189         ST07       395007  Petrol  Individual  ...     5    Y           1
# 274         ST15       400001  Petrol  Individual  ...     5    Y           1
#
# ...

# %% [markdown]
# #### verified car_model_Range logic with 2005 year test case ####

# %%
#df_used_cars_rep.drop(['car_model_range'],axis=1,inplace=True)

# %% [markdown]
# #df_used_cars_rep.dtypes
# df_used_cars_rep['approx_Mileage'] = df_used_cars_rep['Mileage'].str.split(' ', 1).str[0].astype('float64').apply(np.ceil)

# %% [markdown]
# #### added approx_Mileage column by taking ceil function and stored it in df_used_cars_rep dataframe ####

# %%
df_used_cars_rep['approx_Mileage'] = df_used_cars_rep['Mileage'].astype('str')

# %% [markdown]
# #### changed the datatype of car_model_range to string ####

# %%
df_used_cars_rep['km_Driven_range'] = df_used_cars_rep['km_Driven_range'].astype('object')

# %%
#### changed the datatype of km_Driven_range to object ####

# %%
df_used_cars_rep['car_model_range'] = df_used_cars_rep['car_model_range'].astype('object')

# %% [markdown]
# #### changed the datatype of car_model_range to object ####

# %%
df_used_cars_rep.dtypes
# Out:
# Sales_ID             int64
# Name                object
# Year                 int64
# Selling_Price      float64
# km_Driven            int64
# City_Code           object
# State_Code_x        object
# Postal_Code          int64
# Fuel                object
# Seller_Type         object
# Transmission        object
# Owner               object
# Mileage             object
# Engine              object
# Max_Power           object
# Seats                int64
# Sold                object
# Sold_Mapped          int64
# State_Name          object
# City_Name           object
# Region_Code         object
# Region              object
# Brand               object
# km_Driven_range     object
# car_model_range     object
# approx_Mileage      object
# dtype: object

# %%
#Minimum Selling price for different brands(Considering all models) in all region for sold models:

paramter_check = ['Brand','Year','Name','Region','State_Name','City_Name','Seller_Type','km_Driven','Fuel','Engine','Seats','Transmission','Owner','Mileage','Max_Power']
df_min_selling_price = df_used_cars_rep.query("Sold == 'Y'").groupby(paramter_check,as_index=False).agg({'Selling_Price':np.min}).rename(columns={'Selling_Price':'Min_Selling_Price_in_lakhs'}).sort_values(by=['Name','km_Driven'],ascending=[True,True])
#df_used_cars_rep.query("Sold == 'Y' & Region=='East'").groupby(['Brand','Name','Region','State_Name','City_Name'],as_index=False).size().sort_values('size',ascending=False).head(15)

# %% [markdown]
# #### Minimum Selling price required for different brands(Considering all models) in all region for sold models ####

# %%
df_min_selling_price.Min_Selling_Price_in_lakhs = df_min_selling_price.Min_Selling_Price_in_lakhs/100000

# %% [markdown]
# #### divided with 100000 to convert  in terms of lakhs ####

# %%
"""
km_Driven_range = [0,5000, 10000, 20000, 40000, 80000,160000,200000,250000,np.inf]
#names = ['<5K', '10K-20K', '20K-40K', '40K-80K', '80K-160K','160K-200K','200K-250K','250K+']
names = ['0-5K', '5K-10K', '10K-20K', '20K-40K', '40K-80K','80K-160K','160K-200K','200K-250K','250K+']
df_min_selling_price['km_Driven_range'] = pd.cut(df_min_selling_price['km_Driven'], km_Driven_range, labels=names)
""""

# %%
"""

car_model_range = [0,1999,2005, 2011, 2015,2018,np.inf]

names = ['Antique(upto 1999)', 'Very Old(2000-2005)', 'Old(2006-2011)','Moderate(2012-2015)','Fair(2016-2018)','New(2019+)']
df_min_selling_price['car_model_range'] = pd.cut(df_min_selling_price['Year'], car_model_range, labels=names)

"""

# %%
df_min_selling_price['approx_Mileage'] = df_min_selling_price['Mileage'].str.split(' ', 1).str[0].astype('float64').apply(np.ceil)

# %% [markdown]
# #### added approx_Mileage column to df_min_selling_price dataframe ####

# %%
df_min_selling_price['approx_Mileage'] = df_min_selling_price['approx_Mileage'].astype('str')

# %%
df_min_selling_price.km_Driven_range = df_min_selling_price.km_Driven_range.astype('object')

# %%
df_min_selling_price.car_model_range = df_min_selling_price.car_model_range.astype('object')

# %%
df_min_selling_price.columns
# Out:
# Index(['Brand', 'Year', 'Name', 'Region', 'State_Name', 'City_Name',
#        'Seller_Type', 'km_Driven', 'Fuel', 'Engine', 'Seats', 'Transmission',
#        'Owner', 'Mileage', 'Max_Power', 'Min_Selling_Price_in_lakhs',
#        'km_Driven_range', 'car_model_range', 'approx_Mileage'],
#       dtype='object')

# %%
df_min_selling_price.head(5)
# Out:
#   Brand  Year                                  Name Region      State_Name  \
# 3  Audi  2014                       Audi A4 2.0 TDI   East       Jharkhand
# 1  Audi  2013       Audi A6 2.0 TDI  Design Edition   West         Gujarat
# 2  Audi  2013            Audi A6 2.0 TDI Technology   West         Gujarat
# 5  Audi  2017  Audi Q3 2.0 TDI Quattro Premium Plus  South  Andhra Pradesh
# 0  Audi  2011                       Audi Q5 2.0 TDI  North           Delhi
#
#    City_Name Seller_Type  km_Driven    Fuel   Engine  Seats Transmission  \
# 3     Ranchi  Individual      44000  Diesel  1968 CC      5    Automatic
# 1  Ahmedabad      Dealer      50000  Diesel  1968 CC      5    Automatic
# 2  Ahmedabad      Dealer      33900  Diesel  1968 CC      5    Automatic
# 5    Nellore      Dealer      22000  Diesel  1968 CC      5    Automatic
# 0      Delhi  Individual     120000  Diesel  1968 CC      5    Automatic
#
#           Owner     Mileage   Max_Power  Min_Selling_Price_in_lakhs  \
# ...

# %%
# Big Brands Analysis ('BMW','Audi')... first preference is Km_Driven...almost every car is Diesel
#index_data = ['Brand','Year','Name','Region','State_Name','City_Name','km_Driven','Mileage','Max_Power','Fuel','Engine','Seats','Transmission']
index_data = ['Brand','Year','Name','km_Driven','Seller_Type','Owner','Mileage','Max_Power','Fuel','Engine','Seats','Transmission']
df_check_brand_min_Selling_price = df_min_selling_price.query("Brand=='Audi' | Brand=='BMW'")
pd.pivot_table(df_check_brand_min_Selling_price,values=['Min_Selling_Price_in_lakhs'],index =index_data,columns=['car_model_range','km_Driven_range']).fillna(0).sort_values(by = ['Year','Name',],ascending=[True,True])
# Out:
#                                                                                                                                            Min_Selling_Price_in_lakhs  \
# car_model_range                                                                                                                                       Fair(2016-2018)
# km_Driven_range                                                                                                                                               10K-20K
# Brand Year Name                                 km_Driven Seller_Type Owner        Mileage    Max_Power  Fuel   Engine  Seats Transmission
# BMW   2010 BMW 5 Series 523i                    72200     Dealer      Second Owner 10.8 kmpl  150 bhp    Petrol 2497 CC 5     Automatic                           0.0
# Audi  2011 Audi Q5 2.0 TDI                      120000    Individual  First Owner  12.8 kmpl  167.6 bhp  Diesel 1968 CC 5     Automatic                           0.0
# ...

# %% [markdown]
# #### Analysed for Big brands Audi and BMW and stored displayed using pivot table
# #### Almost all cars are diesel and displayed minimum selling price w.r.t car model and km_driven range

# %%
# Most sold Brand Analysis ('Maruti')-- [Maruti,Petrol,Manual]
#Clearly Diesel cars have more price than Petrol cars and  Transmission automatic has high price..
index_data = ['Brand','Year','Name','km_Driven','Seller_Type','Owner','Mileage','Max_Power','Fuel','Engine','Seats','Transmission']
df_check_brand_min_Selling_price = df_min_selling_price.query("Brand=='Maruti' & Fuel=='Petrol' & Transmission=='Manual'")
pd.pivot_table(df_check_brand_min_Selling_price,values=['Min_Selling_Price_in_lakhs'],index =index_data,columns=['car_model_range','km_Driven_range']).fillna(0).sort_values(by = ['Year','Name',],ascending=[True,True])
# Out:
#                                                                                                                                  Min_Selling_Price_in_lakhs  \
# car_model_range                                                                                                                          Antique(upto 1999)
# km_Driven_range                                                                                                                                     20K-40K
# Brand  Year Name                       km_Driven Seller_Type Owner        Mileage    Max_Power Fuel   Engine  Seats Transmission
# Maruti 1994 Maruti 800 AC              60000     Individual  First Owner  16.1 kmpl  37 bhp    Petrol 796 CC  4     Manual                              0.0
#        1999 Maruti 800 AC              60000     Individual  Second Owner 16.1 kmpl  37 bhp    Petrol 796 CC  4     Manual                              0.0
# ...

# %% [markdown]
# #### displayed in pivot table for mostly sold car Maruti and

# %%
# Most sold Brand Analysis ('Maruti')-- [Maruti,Petrol,Automatic]
#Clearly Diesel cars have more price than Petrol cars and  Transmission automatic has high price..
index_data = ['Brand','Year','Name','Seller_Type','km_Driven','Mileage','Max_Power','Fuel','Engine','Seats','Transmission']
df_check_brand_min_Selling_price = df_min_selling_price.query("Brand=='Maruti' & Fuel=='Petrol' & Transmission=='Automatic'")
pd.pivot_table(df_check_brand_min_Selling_price,values=['Min_Selling_Price_in_lakhs'],index =index_data,columns=['car_model_range','km_Driven_range']).fillna(0).sort_values(by = ['Year','Name',],ascending=[True,True])
# Out:
#                                                                                                                                Min_Selling_Price_in_lakhs  \
# car_model_range                                                                                                                           Fair(2016-2018)
# km_Driven_range                                                                                                                                      0-5K
# Brand  Year Name                             Seller_Type      km_Driven Mileage    Max_Power Fuel   Engine  Seats Transmission
# Maruti 2006 Maruti Wagon R AX                Individual       60000     18.9 kmpl  67.1 bhp  Petrol 998 CC  5     Automatic                           0.0
#        2011 Maruti SX4 ZXI AT                Individual       65000     12.6 kmpl  103.3 bhp Petrol 1586 CC 5     Automatic                           0.0
# ...

# %% [markdown]
# - Sample
# - Sample1

# %%
df_min_selling_price.Brand.unique()
# Out:
# array(['Audi', 'BMW', 'Chevrolet', 'Daewoo', 'Datsun', 'Fiat', 'Force',
#        'Ford', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Kia', 'Land',
#        'Lexus', 'MG', 'Mahindra', 'Maruti', 'Mercedes-Benz', 'Mitsubishi',
#        'Nissan', 'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
df_min_selling_price.Seller_Type.unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %%
# Most sold Brand Analysis ('Maruti') -- [Maruti,Diesel,Manual]
#Clearly Diesel cars have more price with Transmission Automatic..
index_data = ['Brand','Year','Name','Seller_Type','km_Driven','Mileage','Max_Power','Fuel','Engine','Seats','Transmission']
df_check_brand_min_Selling_price = df_min_selling_price.query("Brand=='Maruti' & Fuel=='Diesel' & Transmission=='Manual'")
pd.pivot_table(df_check_brand_min_Selling_price,values=['Min_Selling_Price_in_lakhs'],index =index_data,columns=['car_model_range','km_Driven_range']).fillna(0).sort_values(by = ['Year','Name',],ascending=[True,True])
# Out:
#                                                                                                                         Min_Selling_Price_in_lakhs  \
# car_model_range                                                                                                                    Fair(2016-2018)
# km_Driven_range                                                                                                                               0-5K
# Brand  Year Name                            Seller_Type km_Driven Mileage   Max_Power Fuel   Engine  Seats Transmission
# Maruti 2003 Maruti Zen D                    Individual  120000    20.8 kmpl 58 bhp    Diesel 1527 CC 5     Manual                              0.0
#        2008 Maruti Swift Dzire LDi          Individual  80000     19.3 kmpl 73.9 bhp  Diesel 1248 CC 5     Manual                              0.0
# ...

# %%
# Most sold Brand Analysis ('Maruti') -- [Maruti,Diesel,Automatic]
#Clearly Diesel cars have more price with Transmission Automatic..
index_data = ['Brand','Year','Name','Seller_Type','km_Driven','Mileage','Max_Power','Fuel','Engine','Seats','Transmission']
df_check_brand_min_Selling_price = df_min_selling_price.query("Brand=='Maruti' & Fuel=='Diesel' & Transmission=='Automatic'")
pd.pivot_table(df_check_brand_min_Selling_price,values=['Min_Selling_Price_in_lakhs'],index =index_data,columns=['car_model_range','km_Driven_range']).fillna(0).sort_values(by = ['Year','Name',],ascending=[True,True])
# Out:
#                                                                                                                                      Min_Selling_Price_in_lakhs  \
# car_model_range                                                                                                                                 Fair(2016-2018)
# km_Driven_range                                                                                                                                         10K-20K
# Brand  Year Name                                        Seller_Type km_Driven Mileage    Max_Power Fuel   Engine  Seats Transmission
# Maruti 2016 Maruti Swift Dzire AMT ZDI                  Individual  50000     26.59 kmpl 74 bhp    Diesel 1248 CC 5     Automatic                           0.0
#        2017 Maruti Ignis 1.3 AMT Zeta                   Individual  37000     26.8 kmpl  74 bhp    Diesel 1248 CC 5     Automatic                           0.0
# ...

# %%
#df_check_brand_min_Selling_price.km_Driven_range = df_check_brand_min_Selling_price.km_Driven_range.astype('object')
#km_Driven_range
#car_model_range
df_check_brand_min_Selling_price.dtypes
# Out:
# Brand                          object
# Year                            int64
# Name                           object
# Region                         object
# State_Name                     object
# City_Name                      object
# Seller_Type                    object
# km_Driven                       int64
# Fuel                           object
# Engine                         object
# Seats                           int64
# Transmission                   object
# Owner                          object
# Mileage                        object
# Max_Power                      object
# Min_Selling_Price_in_lakhs    float64
# km_Driven_range                object
# car_model_range                object
# approx_Mileage                 object
# dtype: object

# %%
input_dict = {'Brand':'Maruti','Fuel':'Diesel','approx_Mileage':'25.0'}

# %%
#Amalysis of min selling price for varius model from user inputs...

df_input_used_cars_rep = df_min_selling_price[(df_min_selling_price[''.join(list(input_dict.keys())[0])]==''.join(list(input_dict.values())[0])) & (df_min_selling_price[''.join(list(input_dict.keys())[1])]==''.join(list(input_dict.values())[1])) & (df_min_selling_price[''.join(list(input_dict.keys())[2])]==''.join(list(input_dict.values())[2]))]

# %%
df_input_used_cars_rep.head(5)
# Out:
#        Brand  Year                           Name Region State_Name  \
# 1405  Maruti  2018          Maruti Ertiga 1.5 VDI  South  Karnataka
# 1275  Maruti  2016  Maruti Ertiga SHVS LDI Option  South     Kerala
# 1277  Maruti  2016         Maruti Ertiga SHVS VDI  South     Kerala
# 1276  Maruti  2016         Maruti Ertiga SHVS VDI  South  Karnataka
# 1330  Maruti  2017         Maruti Ertiga SHVS VDI  South     Kerala
#
#       City_Name Seller_Type  km_Driven    Fuel   Engine  Seats Transmission  \
# 1405  Mangalore  Individual      59000  Diesel  1498 CC      7       Manual
# 1275      Kochi  Individual      70000  Diesel  1248 CC      7       Manual
# 1277      Kochi  Individual      70000  Diesel  1248 CC      7       Manual
# 1276  Mangalore  Individual      80000  Diesel  1248 CC      7       Manual
# 1330      Kochi  Individual      80000  Diesel  1248 CC      7       Manual
#
#              Owner     Mileage  Max_Power  Min_Selling_Price_in_lakhs  \
# ...

# %%
input_check = ['Brand','Year','Name','Seller_Type','km_Driven','Mileage','Max_Power','Fuel','Engine','Seats','Transmission']
pd.pivot_table(df_input_used_cars_rep,values=['Min_Selling_Price_in_lakhs'],index =input_check,columns=['car_model_range','km_Driven_range']).head(10).fillna(0).sort_values(by =['Year','Name'],ascending=[True,True])
# Out:
#                                                                                                                                  Min_Selling_Price_in_lakhs  \
# car_model_range                                                                                                                             Fair(2016-2018)
# km_Driven_range                                                                                                                                        0-5K
# Brand  Year Name                                    Seller_Type km_Driven Mileage    Max_Power Fuel   Engine  Seats Transmission
# Maruti 2016 Maruti Ertiga SHVS LDI Option           Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual                              0.0
#             Maruti Ertiga SHVS VDI                  Individual  70000     24.52 kmpl 88.5 bhp  Diesel 1248 CC 7     Manual                              0.0
# ...
